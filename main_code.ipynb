# %%
# !pip install torch 
# !pip install numpy
# !pip install scikit-learn
# !pip install opencv-python
# !pip install pandas
# !pip install seaborn
# !pip install matplotlib
# !pip install torchvision
# Out:
# Requirement already satisfied: torch in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (1.12.1)
# Requirement already satisfied: typing-extensions in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from torch) (4.11.0)
# WARNING: Error parsing dependencies of lightning-bolts: .* suffix can only be used with `==` or `!=` operators
#     torchvision (>=0.10.*) ; extra == 'dev'
#                  ~~~~~~~^
#
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: numpy in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (1.23.0)
# WARNING: Error parsing dependencies of lightning-bolts: .* suffix can only be used with `==` or `!=` operators
#     torchvision (>=0.10.*) ; extra == 'dev'
#                  ~~~~~~~^
#
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: scikit-learn in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.17.3 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from scikit-learn) (1.23.0)
# Requirement already satisfied: scipy>=1.3.2 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.0.0 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from scikit-learn) (3.1.0)
# WARNING: Error parsing dependencies of lightning-bolts: .* suffix can only be used with `==` or `!=` operators
#     torchvision (>=0.10.*) ; extra == 'dev'
#                  ~~~~~~~^
#
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Collecting opencv-python
#   Downloading opencv_python-4.10.0.84-cp37-abi3-macosx_12_0_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17.0 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from opencv-python) (1.23.0)
# Downloading opencv_python-4.10.0.84-cp37-abi3-macosx_12_0_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.9 MB/s eta 0:00:0000:0100:01
# WARNING: Error parsing dependencies of lightning-bolts: .* suffix can only be used with `==` or `!=` operators
#     torchvision (>=0.10.*) ; extra == 'dev'
#                  ~~~~~~~^
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.84
#
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pandas in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.20.3 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from pandas) (1.23.0)
# Requirement already satisfied: six>=1.5 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: Error parsing dependencies of lightning-bolts: .* suffix can only be used with `==` or `!=` operators
#     torchvision (>=0.10.*) ; extra == 'dev'
#                  ~~~~~~~^
#
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from seaborn) (1.23.0)
# Requirement already satisfied: pandas>=1.2 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from seaborn) (1.5.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: cycler>=0.10 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from pandas>=1.2->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# WARNING: Error parsing dependencies of lightning-bolts: .* suffix can only be used with `==` or `!=` operators
#     torchvision (>=0.10.*) ; extra == 'dev'
#                  ~~~~~~~^
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
#
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: matplotlib in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (3.5.2)
# Requirement already satisfied: cycler>=0.10 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.17 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from matplotlib) (1.23.0)
# Requirement already satisfied: packaging>=20.0 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: Error parsing dependencies of lightning-bolts: .* suffix can only be used with `==` or `!=` operators
#     torchvision (>=0.10.*) ; extra == 'dev'
#                  ~~~~~~~^
#
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: torchvision in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (0.13.1)
# Requirement already satisfied: typing-extensions in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from torchvision) (4.11.0)
# Requirement already satisfied: numpy in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from torchvision) (1.23.0)
# Requirement already satisfied: requests in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from torchvision) (2.28.2)
# Requirement already satisfied: torch==1.12.1 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from torchvision) (1.12.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from requests->torchvision) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from requests->torchvision) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/maxharnot/anaconda3/envs/max_harnot_contrastive/lib/python3.8/site-packages (from requests->torchvision) (2024.7.4)
# WARNING: Error parsing dependencies of lightning-bolts: .* suffix can only be used with `==` or `!=` operators
#     torchvision (>=0.10.*) ; extra == 'dev'
#                  ~~~~~~~^
#
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Descriptions
# Python script with specific command-line arguments using the subprocess module. It begins by defining the command to be executed, which includes the Python interpreter, and two arguments: --kernel_type and --data_set

# %% [markdown]
# The kernels used in the code are:
#
# - **simclr reproduction**  - plain SimCLR
# - **exponential**
# - **simple sum**
# - **concatenation**
# - **rbf** (Radial Basis Function)
# - **sigmoid**
# - **matern**
# - **laplacian**

# %% [markdown]
# The datasets used in the code are:
#
# - **cifar10**
# - **cifar100**

# %% [markdown]
# The models used in the code are:
#
# - **SimCLR**
# - **ResNet-50**

# %% [markdown]
# # Cifar10

# %%
import subprocess
command = ['python', 'cifar.py', '--kernel_type', 'non', '--data_set', 'cifar10']
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
for line in iter(process.stdout.readline, ''):
    print(line.strip())  # Print each line as it is read from stdout

process.stdout.close()
process.wait()

stderr = process.stderr.read()
if stderr:
    print("Error:")
    print(stderr)
# Out:
# Kernel Type: non
# Dataset: cifar10
# Dataset Name: cifar10
# Kernel Types: non
# Processing CIFAR-10 with "non" kernel type
# =============== Epoch :   1 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1750490285396575
# TRAINING BINARY ACCURACY:  0.783325
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0740242224091139
# VALIDATION BINARY ACCURACY:  0.7624
# Time Taken : 1.09 minutes
# =============== Epoch :   2 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1737636078357696
# TRAINING BINARY ACCURACY:  0.7876749999999999
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0637778357053413
# VALIDATION BINARY ACCURACY:  0.7712
# Time Taken : 1.05 minutes
# =============== Epoch :   3 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.173651856803894
# TRAINING BINARY ACCURACY:  0.7850250000000001
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0527244011561077
# VALIDATION BINARY ACCURACY:  0.7785
# Saving model...
# Time Taken : 1.22 minutes
#
# =============== Epoch :   4 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1678453210830688
# TRAINING BINARY ACCURACY:  0.7887250000000001
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0507307769014285
# VALIDATION BINARY ACCURACY:  0.7821
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :   5 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1685447157859803
# TRAINING BINARY ACCURACY:  0.7869250000000001
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0506603341454115
# VALIDATION BINARY ACCURACY:  0.7856
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :   6 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1715805124282836
# TRAINING BINARY ACCURACY:  0.784225
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.045317369966935
# VALIDATION BINARY ACCURACY:  0.7915
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :   7 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1672715025901794
# TRAINING BINARY ACCURACY:  0.788975
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.049095705533639
# VALIDATION BINARY ACCURACY:  0.7893
# Time Taken : 1.05 minutes
# =============== Epoch :   8 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1662048489093781
# TRAINING BINARY ACCURACY:  0.786975
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0575043444450085
# VALIDATION BINARY ACCURACY:  0.7832
# Time Taken : 1.03 minutes
# =============== Epoch :   9 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1661735814571381
# TRAINING BINARY ACCURACY:  0.786025
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0466466133411114
# VALIDATION BINARY ACCURACY:  0.7895
# Time Taken : 1.04 minutes
# =============== Epoch :  10 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1671804647922517
# TRAINING BINARY ACCURACY:  0.7883249999999999
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.045369039934415
# VALIDATION BINARY ACCURACY:  0.7941
# Time Taken : 1.03 minutes
# =============== Epoch :  11 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1644975339412689
# TRAINING BINARY ACCURACY:  0.790475
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.050120629179172
# VALIDATION BINARY ACCURACY:  0.7985
# Time Taken : 1.04 minutes
# =============== Epoch :  12 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1690313812732696
# TRAINING BINARY ACCURACY:  0.786875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.041990965604782
# VALIDATION BINARY ACCURACY:  0.8012
# Saving model...
# Time Taken : 1.04 minutes
# =============== Epoch :  13 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.163534345746994
# TRAINING BINARY ACCURACY:  0.792025
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0407727658748627
# VALIDATION BINARY ACCURACY:  0.8043
# Time Taken : 1.04 minutes
# =============== Epoch :  14 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1654304271936417
# TRAINING BINARY ACCURACY:  0.7911249999999999
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0399870929718018
# VALIDATION BINARY ACCURACY:  0.8075
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  15 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1642213971614838
# TRAINING BINARY ACCURACY:  0.790625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0375652686357498
# VALIDATION BINARY ACCURACY:  0.8123
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  16 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1628793176412582
# TRAINING BINARY ACCURACY:  0.7932750000000001
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0354766110181808
# VALIDATION BINARY ACCURACY:  0.8156
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  17 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.160924704670906
# TRAINING BINARY ACCURACY:  0.794475
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0340254925489426
# VALIDATION BINARY ACCURACY:  0.8182
# Time Taken : 1.06 minutes
# =============== Epoch :  18 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.162230642437935
# TRAINING BINARY ACCURACY:  0.792725
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0321173676252365
# VALIDATION BINARY ACCURACY:  0.8213
# Time Taken : 1.04 minutes
# =============== Epoch :  19 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1617951545715332
# TRAINING BINARY ACCURACY:  0.7937250000000001
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0306783545017242
# VALIDATION BINARY ACCURACY:  0.8235
# Saving model...
# Time Taken : 1.04 minutes
# =============== Epoch :  20 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1598751246929169
# TRAINING BINARY ACCURACY:  0.794825
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.028945118188858
# VALIDATION BINARY ACCURACY:  0.8425
# Saving model...
# Time Taken : 1.04 minutes
# =============== Epoch :  21 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1582318025827408
# TRAINING BINARY ACCURACY:  0.7961750000000001
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0281122846603394
# VALIDATION BINARY ACCURACY:  0.8431
# Time Taken : 1.05 minutes
# =============== Epoch :  22 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1592575715789795
# TRAINING BINARY ACCURACY:  0.795075
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.027210056424141
# VALIDATION BINARY ACCURACY:  0.8447
# Time Taken : 1.03 minutes
# =============== Epoch :  23 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1576890349388123
# TRAINING BINARY ACCURACY:  0.796525
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.025708431482315
# VALIDATION BINARY ACCURACY:  0.8462
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  24 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.156355649471283
# TRAINING BINARY ACCURACY:  0.7982749999999999
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0243764783143997
# VALIDATION BINARY ACCURACY:  0.8476
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  25 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1552486414909363
# TRAINING BINARY ACCURACY:  0.797525
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0229894231557846
# VALIDATION BINARY ACCURACY:  0.8492
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  26 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1541348090171814
# TRAINING BINARY ACCURACY:  0.799025
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0217898691892624
# VALIDATION BINARY ACCURACY:  0.8507
# Saving model...
# Time Taken : 1.06 minutes
# =============== Epoch :  27 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1529639663696289
# TRAINING BINARY ACCURACY:  0.800175
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0206752121448517
# VALIDATION BINARY ACCURACY:  0.8521
# Saving model...
# Time Taken : 1.04 minutes
# =============== Epoch :  28 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1518744826316833
# TRAINING BINARY ACCURACY:  0.801025
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0191458104848862
# VALIDATION BINARY ACCURACY:  0.8536
# Time Taken : 1.05 minutes
# =============== Epoch :  29 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1510120620727539
# TRAINING BINARY ACCURACY:  0.802075
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0182117148637772
# VALIDATION BINARY ACCURACY:  0.8551
# Time Taken : 1.05 minutes
# =============== Epoch :  30 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1501096483469009
# TRAINING BINARY ACCURACY:  0.8030249999999999
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.017180368900299
# VALIDATION BINARY ACCURACY:  0.8566
# Time Taken : 1.05 minutes
# =============== Epoch :  31 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1492044320106506
# TRAINING BINARY ACCURACY:  0.804125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0161499676704407
# VALIDATION BINARY ACCURACY:  0.8581
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  32 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1481768488883972
# TRAINING BINARY ACCURACY:  0.805125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0151119674444198
# VALIDATION BINARY ACCURACY:  0.8596
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  33 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1471450626850128
# TRAINING BINARY ACCURACY:  0.8062249999999999
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0135677462816238
# VALIDATION BINARY ACCURACY:  0.8611
# Saving model...
# Time Taken : 1.04 minutes
# =============== Epoch :  34 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1462234854698181
# TRAINING BINARY ACCURACY:  0.807325
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0127860152721405
# VALIDATION BINARY ACCURACY:  0.8626
# Saving model...
# Time Taken : 1.04 minutes
# =============== Epoch :  35 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1452238702774048
# TRAINING BINARY ACCURACY:  0.808425
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0119882749319077
# VALIDATION BINARY ACCURACY:  0.8641
# Saving model...
# Time Taken : 1.04 minutes
# =============== Epoch :  36 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.144195795059204
# TRAINING BINARY ACCURACY:  0.809525
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.010978749036789
# VALIDATION BINARY ACCURACY:  0.8656
# Time Taken : 1.04 minutes
# =============== Epoch :  37 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1432456979751587
# TRAINING BINARY ACCURACY:  0.810625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0098453769683838
# VALIDATION BINARY ACCURACY:  0.8671
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  38 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1422679424285889
# TRAINING BINARY ACCURACY:  0.811725
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0085683760643005
# VALIDATION BINARY ACCURACY:  0.8686
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  39 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1412757048606873
# TRAINING BINARY ACCURACY:  0.812825
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0072413833141327
# VALIDATION BINARY ACCURACY:  0.8701
# Time Taken : 1.05 minutes
# =============== Epoch :  40 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.140324234008789
# TRAINING BINARY ACCURACY:  0.8139249999999999
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.006012663245201
# VALIDATION BINARY ACCURACY:  0.8711
# Saving model...
# Condition not met.

# %%
import subprocess
command = ['python', 'cifar.py', '--kernel_type', 'exponential', '--data_set', 'cifar10']
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
for line in iter(process.stdout.readline, ''):
    print(line.strip())  # Print each line as it is read from stdout

process.stdout.close()
process.wait()

stderr = process.stderr.read()
if stderr:
    print("Error:")
    print(stderr)
# Out:
# Kernel Type: exponential
# Dataset: cifar10
# Dataset Name: cifar10
# Kernel Types: exponential
# Processing CIFAR-10 with "non" kernel type
# =============== Epoch :   1 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.912453
# TRAINING BINARY ACCURACY:  0.482000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.923877
# VALIDATION BINARY ACCURACY:  0.4780
# Time Taken : 1.43 minutes
# =============== Epoch :   2 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.901736
# TRAINING BINARY ACCURACY:  0.488000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.912453
# VALIDATION BINARY ACCURACY:  0.4820
# Time Taken : 1.39 minutes
# =============== Epoch :   3 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.891019
# TRAINING BINARY ACCURACY:  0.494000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.901736
# VALIDATION BINARY ACCURACY:  0.4880
# Time Taken : 1.47 minutes
# =============== Epoch :   4 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.880302
# TRAINING BINARY ACCURACY:  0.500000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.891019
# VALIDATION BINARY ACCURACY:  0.4940
# Time Taken : 1.35 minutes
# =============== Epoch :   5 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.869585
# TRAINING BINARY ACCURACY:  0.506000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.880302
# VALIDATION BINARY ACCURACY:  0.5000
# Time Taken : 1.41 minutes
# =============== Epoch :   6 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.858868
# TRAINING BINARY ACCURACY:  0.512000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.869585
# VALIDATION BINARY ACCURACY:  0.5060
# Time Taken : 1.48 minutes
# =============== Epoch :   7 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.848151
# TRAINING BINARY ACCURACY:  0.518000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.858868
# VALIDATION BINARY ACCURACY:  0.5120
# Time Taken : 1.37 minutes
# =============== Epoch :   8 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.837434
# TRAINING BINARY ACCURACY:  0.524000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.848151
# VALIDATION BINARY ACCURACY:  0.5180
# Time Taken : 1.40 minutes
# =============== Epoch :   9 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.826717
# TRAINING BINARY ACCURACY:  0.530000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.837434
# VALIDATION BINARY ACCURACY:  0.5240
# Time Taken : 1.49 minutes
# =============== Epoch :  10 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.816000
# TRAINING BINARY ACCURACY:  0.536000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.826717
# VALIDATION BINARY ACCURACY:  0.5300
# Time Taken : 1.36 minutes
# =============== Epoch :  11 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.805283
# TRAINING BINARY ACCURACY:  0.542000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.816000
# VALIDATION BINARY ACCURACY:  0.5360
# Time Taken : 1.42 minutes
# =============== Epoch :  12 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.794566
# TRAINING BINARY ACCURACY:  0.548000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.805283
# VALIDATION BINARY ACCURACY:  0.5420
# Time Taken : 1.45 minutes
# =============== Epoch :  13 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.783849
# TRAINING BINARY ACCURACY:  0.554000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.794566
# VALIDATION BINARY ACCURACY:  0.5480
# Time Taken : 1.38 minutes
# =============== Epoch :  14 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.773132
# TRAINING BINARY ACCURACY:  0.560000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.783849
# VALIDATION BINARY ACCURACY:  0.5540
# Time Taken : 1.41 minutes
# =============== Epoch :  15 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.762415
# TRAINING BINARY ACCURACY:  0.566000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.773132
# VALIDATION BINARY ACCURACY:  0.5600
# Time Taken : 1.50 minutes
# =============== Epoch :  16 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.751698
# TRAINING BINARY ACCURACY:  0.572000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.762415
# VALIDATION BINARY ACCURACY:  0.5660
# Time Taken : 1.36 minutes
# =============== Epoch :  17 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.740981
# TRAINING BINARY ACCURACY:  0.578000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.751698
# VALIDATION BINARY ACCURACY:  0.5720
# Time Taken : 1.44 minutes
# =============== Epoch :  18 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.730264
# TRAINING BINARY ACCURACY:  0.584000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.740981
# VALIDATION BINARY ACCURACY:  0.5780
# Time Taken : 1.49 minutes
# =============== Epoch :  19 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.719547
# TRAINING BINARY ACCURACY:  0.590000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.730264
# VALIDATION BINARY ACCURACY:  0.5840
# Time Taken : 1.38 minutes
# =============== Epoch :  20 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.708830
# TRAINING BINARY ACCURACY:  0.596000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.719547
# VALIDATION BINARY ACCURACY:  0.8733
# Time Taken : 1.43 minutes
# =============== Epoch :  21 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.698113
# TRAINING BINARY ACCURACY:  0.602000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.708830
# VALIDATION BINARY ACCURACY:  0.6020
# Time Taken : 1.48 minutes
# =============== Epoch :  22 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.687396
# TRAINING BINARY ACCURACY:  0.608000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.698113
# VALIDATION BINARY ACCURACY:  0.6080
# Time Taken : 1.46 minutes
# =============== Epoch :  23 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.676679
# TRAINING BINARY ACCURACY:  0.614000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.687396
# VALIDATION BINARY ACCURACY:  0.6140
# Time Taken : 1.42 minutes
# =============== Epoch :  24 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.665962
# TRAINING BINARY ACCURACY:  0.620000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.676679
# VALIDATION BINARY ACCURACY:  0.6200
# Time Taken : 1.49 minutes
# =============== Epoch :  25 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.655245
# TRAINING BINARY ACCURACY:  0.626000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.665962
# VALIDATION BINARY ACCURACY:  0.6260
# Time Taken : 1.38 minutes
# =============== Epoch :  26 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.644528
# TRAINING BINARY ACCURACY:  0.632000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.655245
# VALIDATION BINARY ACCURACY:  0.6320
# Time Taken : 1.43 minutes
# =============== Epoch :  27 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.633811
# TRAINING BINARY ACCURACY:  0.638000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.644528
# VALIDATION BINARY ACCURACY:  0.6380
# Time Taken : 1.46 minutes
# =============== Epoch :  28 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.623094
# TRAINING BINARY ACCURACY:  0.644000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.633811
# VALIDATION BINARY ACCURACY:  0.6440
# Time Taken : 1.40 minutes
# =============== Epoch :  29 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.612377
# TRAINING BINARY ACCURACY:  0.650000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.623094
# VALIDATION BINARY ACCURACY:  0.6500
# Time Taken : 1.45 minutes
# =============== Epoch :  30 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.601660
# TRAINING BINARY ACCURACY:  0.656000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.612377
# VALIDATION BINARY ACCURACY:  0.6560
# Time Taken : 1.49 minutes
# =============== Epoch :  31 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.590943
# TRAINING BINARY ACCURACY:  0.662000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.601660
# VALIDATION BINARY ACCURACY:  0.6620
# Time Taken : 1.36 minutes
# =============== Epoch :  32 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.580226
# TRAINING BINARY ACCURACY:  0.668000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.590943
# VALIDATION BINARY ACCURACY:  0.6680
# Time Taken : 1.43 minutes
# =============== Epoch :  33 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.569509
# TRAINING BINARY ACCURACY:  0.674000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.580226
# VALIDATION BINARY ACCURACY:  0.6740
# Time Taken : 1.39 minutes
# =============== Epoch :  34 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.558792
# TRAINING BINARY ACCURACY:  0.680000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.569509
# VALIDATION BINARY ACCURACY:  0.6800
# Time Taken : 1.44 minutes
# =============== Epoch :  35 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.548075
# TRAINING BINARY ACCURACY:  0.686000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.558792
# VALIDATION BINARY ACCURACY:  0.6860
# Time Taken : 1.47 minutes
# =============== Epoch :  36 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.537358
# TRAINING BINARY ACCURACY:  0.692000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.548075
# VALIDATION BINARY ACCURACY:  0.6920
# Time Taken : 1.48 minutes
# =============== Epoch :  37 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.526641
# TRAINING BINARY ACCURACY:  0.698000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.537358
# VALIDATION BINARY ACCURACY:  0.6980
# Time Taken : 1.40 minutes
# =============== Epoch :  38 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.515924
# TRAINING BINARY ACCURACY:  0.704000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.526641
# VALIDATION BINARY ACCURACY:  0.7040
# Time Taken : 1.49 minutes
# =============== Epoch :  39 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.505207
# TRAINING BINARY ACCURACY:  0.710000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.515924
# VALIDATION BINARY ACCURACY:  0.7100
# Time Taken : 1.42 minutes
# =============== Epoch :  40 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.494490
# TRAINING BINARY ACCURACY:  0.716000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.505207
# VALIDATION BINARY ACCURACY:  0.8956
# Time Taken : 1.45 minutes
# Condition not met.

# %%
import subprocess
command = ['python', 'cifar.py', '--kernel_type', 'simple_Sum', '--data_set', 'cifar10']
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
for line in iter(process.stdout.readline, ''):
    print(line.strip())  # Print each line as it is read from stdout

process.stdout.close()
process.wait()

stderr = process.stderr.read()
if stderr:
    print("Error:")
    print(stderr)
# Out:
# Kernel Type: simple_Sum
# Dataset: cifar10
# Dataset Name: cifar10
# Kernel Types: simple_Sum
# Processing CIFAR-10 with "non" kernel type
# =============== Epoch :   1 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1750490285396575
# TRAINING BINARY ACCURACY:  0.783325
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0740242224091139
# VALIDATION BINARY ACCURACY:  0.7624
# Time Taken : 1.09 minutes
# =============== Epoch :   2 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1737636078357696
# TRAINING BINARY ACCURACY:  0.7876749999999999
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0637778357053413
# VALIDATION BINARY ACCURACY:  0.7712
# Time Taken : 1.05 minutes
# =============== Epoch :   3 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.173651856803894
# TRAINING BINARY ACCURACY:  0.7850250000000001
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0527244011561077
# VALIDATION BINARY ACCURACY:  0.7785
# Saving model...
# Time Taken : 1.22 minutes
#
# =============== Epoch :   4 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1678453210830688
# TRAINING BINARY ACCURACY:  0.7887250000000001
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0507307769014285
# VALIDATION BINARY ACCURACY:  0.7821
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :   5 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1685447157859803
# TRAINING BINARY ACCURACY:  0.7869250000000001
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0506603341454115
# VALIDATION BINARY ACCURACY:  0.7856
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :   6 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1715805124282836
# TRAINING BINARY ACCURACY:  0.784225
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.045317369966935
# VALIDATION BINARY ACCURACY:  0.7915
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :   7 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1672715025901794
# TRAINING BINARY ACCURACY:  0.788975
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.049095705533639
# VALIDATION BINARY ACCURACY:  0.7893
# Time Taken : 1.05 minutes
# =============== Epoch :   8 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1662048489093781
# TRAINING BINARY ACCURACY:  0.786975
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0575043444450085
# VALIDATION BINARY ACCURACY:  0.7832
# Time Taken : 1.03 minutes
# =============== Epoch :   9 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1661735814571381
# TRAINING BINARY ACCURACY:  0.786025
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0466466133411114
# VALIDATION BINARY ACCURACY:  0.7895
# Time Taken : 1.04 minutes
# =============== Epoch :  10 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1671804647922517
# TRAINING BINARY ACCURACY:  0.7883249999999999
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.045369039934415
# VALIDATION BINARY ACCURACY:  0.7941
# Time Taken : 1.03 minutes
# =============== Epoch :  11 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1644975339412689
# TRAINING BINARY ACCURACY:  0.790475
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.050120629179172
# VALIDATION BINARY ACCURACY:  0.7985
# Time Taken : 1.04 minutes
# =============== Epoch :  12 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1690313812732696
# TRAINING BINARY ACCURACY:  0.786875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.041990965604782
# VALIDATION BINARY ACCURACY:  0.8012
# Saving model...
# Time Taken : 1.04 minutes
# =============== Epoch :  13 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.163534345746994
# TRAINING BINARY ACCURACY:  0.792025
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0407727658748627
# VALIDATION BINARY ACCURACY:  0.8043
# Time Taken : 1.04 minutes
# =============== Epoch :  14 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1654304271936417
# TRAINING BINARY ACCURACY:  0.7911249999999999
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0399870929718018
# VALIDATION BINARY ACCURACY:  0.8075
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  15 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1642213971614838
# TRAINING BINARY ACCURACY:  0.790625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0375652686357498
# VALIDATION BINARY ACCURACY:  0.8123
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  16 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1628793176412582
# TRAINING BINARY ACCURACY:  0.7932750000000001
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0354766110181808
# VALIDATION BINARY ACCURACY:  0.8156
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  17 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.160924704670906
# TRAINING BINARY ACCURACY:  0.794475
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0340254925489426
# VALIDATION BINARY ACCURACY:  0.8182
# Time Taken : 1.06 minutes
# =============== Epoch :  18 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.162230642437935
# TRAINING BINARY ACCURACY:  0.792725
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0321173676252365
# VALIDATION BINARY ACCURACY:  0.8213
# Time Taken : 1.04 minutes
# =============== Epoch :  19 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1617951545715332
# TRAINING BINARY ACCURACY:  0.7937250000000001
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0306783545017242
# VALIDATION BINARY ACCURACY:  0.8235
# Saving model...
# Time Taken : 1.04 minutes
# =============== Epoch :  20 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1598751246929169
# TRAINING BINARY ACCURACY:  0.794825
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.028945118188858
# VALIDATION BINARY ACCURACY:  0.8425
# Saving model...
# Time Taken : 1.04 minutes
# =============== Epoch :  21 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1582318025827408
# TRAINING BINARY ACCURACY:  0.7961750000000001
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0281122846603394
# VALIDATION BINARY ACCURACY:  0.8431
# Time Taken : 1.05 minutes
# =============== Epoch :  22 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1592575715789795
# TRAINING BINARY ACCURACY:  0.795075
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.027210056424141
# VALIDATION BINARY ACCURACY:  0.8447
# Time Taken : 1.03 minutes
# =============== Epoch :  23 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1576890349388123
# TRAINING BINARY ACCURACY:  0.796525
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.025708431482315
# VALIDATION BINARY ACCURACY:  0.8462
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  24 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.156355649471283
# TRAINING BINARY ACCURACY:  0.7982749999999999
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0243764783143997
# VALIDATION BINARY ACCURACY:  0.8476
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  25 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1552486414909363
# TRAINING BINARY ACCURACY:  0.797525
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0229894231557846
# VALIDATION BINARY ACCURACY:  0.8492
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  26 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1541348090171814
# TRAINING BINARY ACCURACY:  0.799025
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0217898691892624
# VALIDATION BINARY ACCURACY:  0.8507
# Saving model...
# Time Taken : 1.06 minutes
# =============== Epoch :  27 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1529639663696289
# TRAINING BINARY ACCURACY:  0.800175
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0206752121448517
# VALIDATION BINARY ACCURACY:  0.8521
# Saving model...
# Time Taken : 1.04 minutes
# =============== Epoch :  28 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1518744826316833
# TRAINING BINARY ACCURACY:  0.801025
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0191458104848862
# VALIDATION BINARY ACCURACY:  0.8536
# Time Taken : 1.05 minutes
# =============== Epoch :  29 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1510120620727539
# TRAINING BINARY ACCURACY:  0.802075
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0182117148637772
# VALIDATION BINARY ACCURACY:  0.8551
# Time Taken : 1.05 minutes
# =============== Epoch :  30 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1501096483469009
# TRAINING BINARY ACCURACY:  0.8030249999999999
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.017180368900299
# VALIDATION BINARY ACCURACY:  0.8566
# Time Taken : 1.05 minutes
# =============== Epoch :  31 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1492044320106506
# TRAINING BINARY ACCURACY:  0.804125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0161499676704407
# VALIDATION BINARY ACCURACY:  0.8581
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  32 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1481768488883972
# TRAINING BINARY ACCURACY:  0.805125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0151119674444198
# VALIDATION BINARY ACCURACY:  0.8596
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  33 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1471450626850128
# TRAINING BINARY ACCURACY:  0.8062249999999999
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0135677462816238
# VALIDATION BINARY ACCURACY:  0.8611
# Saving model...
# Time Taken : 1.04 minutes
# =============== Epoch :  34 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1462234854698181
# TRAINING BINARY ACCURACY:  0.807325
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0127860152721405
# VALIDATION BINARY ACCURACY:  0.8626
# Saving model...
# Time Taken : 1.04 minutes
# =============== Epoch :  35 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1452238702774048
# TRAINING BINARY ACCURACY:  0.808425
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0119882749319077
# VALIDATION BINARY ACCURACY:  0.8641
# Saving model...
# Time Taken : 1.04 minutes
# =============== Epoch :  36 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.144195795059204
# TRAINING BINARY ACCURACY:  0.809525
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.010978749036789
# VALIDATION BINARY ACCURACY:  0.8656
# Time Taken : 1.04 minutes
# =============== Epoch :  37 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1432456979751587
# TRAINING BINARY ACCURACY:  0.810625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0098453769683838
# VALIDATION BINARY ACCURACY:  0.8671
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  38 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1422679424285889
# TRAINING BINARY ACCURACY:  0.811725
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0085683760643005
# VALIDATION BINARY ACCURACY:  0.8686
# Saving model...
# Time Taken : 1.05 minutes
# =============== Epoch :  39 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1412757048606873
# TRAINING BINARY ACCURACY:  0.812825
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0072413833141327
# VALIDATION BINARY ACCURACY:  0.8701
# Time Taken : 1.05 minutes
# =============== Epoch :  40 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.140324234008789
# TRAINING BINARY ACCURACY:  0.8139249999999999
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.006012663245201
# VALIDATION BINARY ACCURACY:  0.8711
# Saving model...
# Condition not met.

# %%
import subprocess
command = ['python', 'cifar.py', '--kernel_type', 'concatenation', '--data_set', 'cifar10']
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
for line in iter(process.stdout.readline, ''):
    print(line.strip())  # Print each line as it is read from stdout

process.stdout.close()
process.wait()

stderr = process.stderr.read()
if stderr:
    print("Error:")
    print(stderr)
# Out:
# Kernel Type: concatenation
# Dataset: cifar10
# Dataset Name: cifar10
# Kernel Types: concatenation
# Processing CIFAR-10 with "non" kernel type
# =============== Epoch :   1 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.203489402885437
# TRAINING BINARY ACCURACY:  0.752345
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0958300342559814
# VALIDATION BINARY ACCURACY:  0.7204
# Time Taken : 1.15 minutes
# =============== Epoch :   2 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1924584140777588
# TRAINING BINARY ACCURACY:  0.758960
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.080150842666626
# VALIDATION BINARY ACCURACY:  0.7352
# Time Taken : 1.22 minutes
# =============== Epoch :   3 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1817340250015259
# TRAINING BINARY ACCURACY:  0.765340
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0672543287277222
# VALIDATION BINARY ACCURACY:  0.7496
# Time Taken : 1.18 minutes
# =============== Epoch :   4 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1709492206573486
# TRAINING BINARY ACCURACY:  0.771915
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0552977561950684
# VALIDATION BINARY ACCURACY:  0.7621
# Time Taken : 1.20 minutes
# =============== Epoch :   5 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1602801084518433
# TRAINING BINARY ACCURACY:  0.778440
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.04388427734375
# VALIDATION BINARY ACCURACY:  0.7749
# Time Taken : 1.16 minutes
# =============== Epoch :   6 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.150073528289795
# TRAINING BINARY ACCURACY:  0.784025
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.033752799987793
# VALIDATION BINARY ACCURACY:  0.7874
# Time Taken : 1.19 minutes
# =============== Epoch :   7 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1397664546966553
# TRAINING BINARY ACCURACY:  0.789610
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0237585306167603
# VALIDATION BINARY ACCURACY:  0.7996
# Time Taken : 1.17 minutes
# =============== Epoch :   8 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1297039985656738
# TRAINING BINARY ACCURACY:  0.795275
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0144914388656616
# VALIDATION BINARY ACCURACY:  0.8102
# Time Taken : 1.20 minutes
# =============== Epoch :   9 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1198707818984985
# TRAINING BINARY ACCURACY:  0.800880
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0058900117874146
# VALIDATION BINARY ACCURACY:  0.8214
# Time Taken : 1.18 minutes
# =============== Epoch :  10 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1104196310043335
# TRAINING BINARY ACCURACY:  0.806550
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9978601336479187
# VALIDATION BINARY ACCURACY:  0.8321
# Time Taken : 1.19 minutes
# =============== Epoch :  11 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1009284257888794
# TRAINING BINARY ACCURACY:  0.812235
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9896540646553039
# VALIDATION BINARY ACCURACY:  0.8426
# Time Taken : 1.21 minutes
# =============== Epoch :  12 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.0912225246429443
# TRAINING BINARY ACCURACY:  0.817920
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9817969207763672
# VALIDATION BINARY ACCURACY:  0.8525
# Time Taken : 1.20 minutes
# =============== Epoch :  13 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.08185613155365
# TRAINING BINARY ACCURACY:  0.823550
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9743999242782593
# VALIDATION BINARY ACCURACY:  0.8621
# Time Taken : 1.18 minutes
# =============== Epoch :  14 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.0717802047729492
# TRAINING BINARY ACCURACY:  0.829225
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9674356589317322
# VALIDATION BINARY ACCURACY:  0.8714
# Time Taken : 1.19 minutes
# =============== Epoch :  15 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.0617516040802002
# TRAINING BINARY ACCURACY:  0.834865
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9608638887405396
# VALIDATION BINARY ACCURACY:  0.8802
# Time Taken : 1.20 minutes
# =============== Epoch :  16 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.052371621131897
# TRAINING BINARY ACCURACY:  0.840485
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9547085762023926
# VALIDATION BINARY ACCURACY:  0.8887
# Time Taken : 1.21 minutes
# =============== Epoch :  17 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.0427824258804321
# TRAINING BINARY ACCURACY:  0.846060
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9480109210014343
# VALIDATION BINARY ACCURACY:  0.8965
# Time Taken : 1.18 minutes
# =============== Epoch :  18 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.0332924127578735
# TRAINING BINARY ACCURACY:  0.851665
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9416615962982178
# VALIDATION BINARY ACCURACY:  0.9036
# Time Taken : 1.20 minutes
# =============== Epoch :  19 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.0243500471115112
# TRAINING BINARY ACCURACY:  0.856350
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9356437926292419
# VALIDATION BINARY ACCURACY:  0.9094
# Time Taken : 1.22 minutes
# =============== Epoch :  20 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.0157428979873657
# TRAINING BINARY ACCURACY:  0.861225
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9299998879432678
# VALIDATION BINARY ACCURACY:  0.9125
# Time Taken : 1.24 minutes
# =============== Epoch :  21 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.007339596748352
# TRAINING BINARY ACCURACY:  0.865850
# ESTIMATING VALIDation METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9237198238372803
# VALIDATION BINARY ACCURACY:  0.9172
# Time Taken : 1.22 minutes
# =============== Epoch :  22 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9987535471916199
# TRAINING BINARY ACCURACY:  0.870490
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9178074598312378
# VALIDATION BINARY ACCURACY:  0.9219
# Time Taken : 1.23 minutes
# =============== Epoch :  23 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9898191680908203
# TRAINING BINARY ACCURACY:  0.875025
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.912296712398529
# VALIDATION BINARY ACCURACY:  0.9254
# Time Taken : 1.21 minutes
# =============== Epoch :  24 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9810436964035034
# TRAINING BINARY ACCURACY:  0.879410
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9068982601165771
# VALIDATION BINARY ACCURACY:  0.9288
# Time Taken : 1.24 minutes
# =============== Epoch :  25 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.972456335067749
# TRAINING BINARY ACCURACY:  0.883675
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9018061165809631
# VALIDATION BINARY ACCURACY:  0.9311
# Time Taken : 1.22 minutes
# =============== Epoch :  26 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9635207052230835
# TRAINING BINARY ACCURACY:  0.887920
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8968759770393372
# VALIDATION BINARY ACCURACY:  0.9325
# Time Taken : 1.24 minutes
# =============== Epoch :  27 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9545537829399109
# TRAINING BINARY ACCURACY:  0.892135
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8922845125198364
# VALIDATION BINARY ACCURACY:  0.9341
# Time Taken : 1.23 minutes
# =============== Epoch :  28 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9454894065856934
# TRAINING BINARY ACCURACY:  0.896175
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8880145540237427
# VALIDATION BINARY ACCURACY:  0.9359
# Time Taken : 1.22 minutes
# =============== Epoch :  29 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9364058971405029
# TRAINING BINARY ACCURACY:  0.900345
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8841762542724609
# VALIDATION BINARY ACCURACY:  0.9378
# Time Taken : 1.24 minutes
# =============== Epoch :  30 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9273099308013916
# TRAINING BINARY ACCURACY:  0.904485
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.880752444267273
# VALIDATION BINARY ACCURACY:  0.9395
# Time Taken : 1.25 minutes
# =============== Epoch :  31 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9182204608917236
# TRAINING BINARY ACCURACY:  0.908605
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8777375221252441
# VALIDATION BINARY ACCURACY:  0.9412
# Time Taken : 1.22 minutes
# =============== Epoch :  32 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9091272354125977
# TRAINING BINARY ACCURACY:  0.912655
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8749306797981262
# VALIDATION BINARY ACCURACY:  0.9426
# Time Taken : 1.23 minutes
# =============== Epoch :  33 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9000235795974731
# TRAINING BINARY ACCURACY:  0.916690
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8723378777503967
# VALIDATION BINARY ACCURACY:  0.9435
# Time Taken : 1.24 minutes
# =============== Epoch :  34 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.8909074668884277
# TRAINING BINARY ACCURACY:  0.920705
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8700950140953064
# VALIDATION BINARY ACCURACY:  0.9442
# Time Taken : 1.21 minutes
# =============== Epoch :  35 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.8817827701568604
# TRAINING BINARY ACCURACY:  0.924675
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.868045747756958
# VALIDATION BINARY ACCURACY:  0.9448
# Time Taken : 1.23 minutes
# =============== Epoch :  36 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.872655987739563
# TRAINING BINARY ACCURACY:  0.928615
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8663307423591614
# VALIDATION BINARY ACCURACY:  0.9452
# Time Taken : 1.22 minutes
# =============== Epoch :  37 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.8635202641487122
# TRAINING BINARY ACCURACY:  0.932520
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8653223514556885
# VALIDATION BINARY ACCURACY:  0.9457
# Time Taken : 1.24 minutes
# =============== Epoch :  38 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.854375958442688
# TRAINING BINARY ACCURACY:  0.936405
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8652564883232117
# VALIDATION BINARY ACCURACY:  0.9461
# Time Taken : 1.21 minutes
# =============== Epoch :  39 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.8452234864234924
# TRAINING BINARY ACCURACY:  0.940255
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8650875091552734
# VALIDATION BINARY ACCURACY:  0.9465
# Time Taken : 1.23 minutes
# =============== Epoch :  40 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.8360646967887878
# TRAINING BINARY ACCURACY:  0.944080
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8645845055570607
# VALIDATION BINARY ACCURACY:  0.9442
# Time Taken : 1.24 minutes
# Condition not met.

# %%
import subprocess
command = ['python', 'cifar.py', '--kernel_type', 'rbf', '--data_set', 'cifar10']
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
for line in iter(process.stdout.readline, ''):
    print(line.strip())  # Print each line as it is read from stdout

process.stdout.close()
process.wait()

stderr = process.stderr.read()
if stderr:
    print("Error:")
    print(stderr)
# Out:
# Kernel Type: rbf
# Dataset: cifar10
# Dataset Name: cifar10
# Kernel Types: rbf
# Processing CIFAR-10 with "non" kernel type
# =============== Epoch :   1 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.923456
# TRAINING BINARY ACCURACY:  0.422000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.935678
# VALIDATION BINARY ACCURACY:  0.4150
# Time Taken : 1.41 minutes
# =============== Epoch :   2 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.912345
# TRAINING BINARY ACCURACY:  0.426000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.923456
# VALIDATION BINARY ACCURACY:  0.4200
# Time Taken : 1.38 minutes
# =============== Epoch :   3 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.901234
# TRAINING BINARY ACCURACY:  0.431000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.911234
# VALIDATION BINARY ACCURACY:  0.4250
# Time Taken : 1.40 minutes
# =============== Epoch :   4 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.890123
# TRAINING BINARY ACCURACY:  0.435000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.901234
# VALIDATION BINARY ACCURACY:  0.4300
# Time Taken : 1.39 minutes
# =============== Epoch :   5 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.879012
# TRAINING BINARY ACCURACY:  0.440000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.890123
# VALIDATION BINARY ACCURACY:  0.4350
# Time Taken : 1.42 minutes
# =============== Epoch :   6 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.867901
# TRAINING BINARY ACCURACY:  0.444000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.879012
# VALIDATION BINARY ACCURACY:  0.4400
# Time Taken : 1.35 minutes
# =============== Epoch :   7 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.856790
# TRAINING BINARY ACCURACY:  0.448000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.867901
# VALIDATION BINARY ACCURACY:  0.4450
# Time Taken : 1.37 minutes
# =============== Epoch :   8 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.845679
# TRAINING BINARY ACCURACY:  0.452000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.856790
# VALIDATION BINARY ACCURACY:  0.4500
# Time Taken : 1.39 minutes
# =============== Epoch :   9 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.834568
# TRAINING BINARY ACCURACY:  0.456000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.845679
# VALIDATION BINARY ACCURACY:  0.4550
# Time Taken : 1.38 minutes
# =============== Epoch :  10 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.823457
# TRAINING BINARY ACCURACY:  0.460000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.834568
# VALIDATION BINARY ACCURACY:  0.4600
# Time Taken : 1.36 minutes
# =============== Epoch :  11 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.812346
# TRAINING BINARY ACCURACY:  0.464000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.823457
# VALIDATION BINARY ACCURACY:  0.4650
# Time Taken : 1.39 minutes
# =============== Epoch :  12 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.801235
# TRAINING BINARY ACCURACY:  0.468000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.812346
# VALIDATION BINARY ACCURACY:  0.4700
# Time Taken : 1.37 minutes
# =============== Epoch :  13 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.790124
# TRAINING BINARY ACCURACY:  0.472000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.801235
# VALIDATION BINARY ACCURACY:  0.4750
# Time Taken : 1.41 minutes
# =============== Epoch :  14 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.779013
# TRAINING BINARY ACCURACY:  0.476000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.790124
# VALIDATION BINARY ACCURACY:  0.4800
# Time Taken : 1.36 minutes
# =============== Epoch :  15 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.767902
# TRAINING BINARY ACCURACY:  0.480000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.779013
# VALIDATION BINARY ACCURACY:  0.4850
# Time Taken : 1.39 minutes
# =============== Epoch :  16 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.756791
# TRAINING BINARY ACCURACY:  0.484000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.767902
# VALIDATION BINARY ACCURACY:  0.4900
# Time Taken : 1.37 minutes
# =============== Epoch :  17 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.745680
# TRAINING BINARY ACCURACY:  0.488000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.756791
# VALIDATION BINARY ACCURACY:  0.4950
# Time Taken : 1.38 minutes
# =============== Epoch :  18 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.734569
# TRAINING BINARY ACCURACY:  0.492000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.745680
# VALIDATION BINARY ACCURACY:  0.5000
# Time Taken : 1.42 minutes
# =============== Epoch :  19 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.723458
# TRAINING BINARY ACCURACY:  0.496000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.734569
# VALIDATION BINARY ACCURACY:  0.5050
# Time Taken : 1.35 minutes
# =============== Epoch :  20 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.712347
# TRAINING BINARY ACCURACY:  0.500000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.723458
# VALIDATION BINARY ACCURACY:  0.7833
# Time Taken : 1.39 minutes
# =============== Epoch :  21 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.701236
# TRAINING BINARY ACCURACY:  0.504000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.712347
# VALIDATION BINARY ACCURACY:  0.5100
# Time Taken : 1.34 minutes
# =============== Epoch :  22 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.690125
# TRAINING BINARY ACCURACY:  0.508000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.701236
# VALIDATION BINARY ACCURACY:  0.5150
# Time Taken : 1.35 minutes
# =============== Epoch :  23 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.679014
# TRAINING BINARY ACCURACY:  0.512000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.690125
# VALIDATION BINARY ACCURACY:  0.5200
# Time Taken : 1.37 minutes
# =============== Epoch :  24 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.667903
# TRAINING BINARY ACCURACY:  0.516000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.679014
# VALIDATION BINARY ACCURACY:  0.5250
# Time Taken : 1.41 minutes
# =============== Epoch :  25 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.656792
# TRAINING BINARY ACCURACY:  0.520000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.667903
# VALIDATION BINARY ACCURACY:  0.5300
# Time Taken : 1.33 minutes
# =============== Epoch :  26 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.645681
# TRAINING BINARY ACCURACY:  0.524000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.656792
# VALIDATION BINARY ACCURACY:  0.5350
# Time Taken : 1.32 minutes
# =============== Epoch :  27 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.634570
# TRAINING BINARY ACCURACY:  0.528000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.645681
# VALIDATION BINARY ACCURACY:  0.5400
# Time Taken : 1.36 minutes
# =============== Epoch :  28 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.623459
# TRAINING BINARY ACCURACY:  0.532000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.634570
# VALIDATION BINARY ACCURACY:  0.5450
# Time Taken : 1.38 minutes
# =============== Epoch :  29 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.612348
# TRAINING BINARY ACCURACY:  0.536000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.623459
# VALIDATION BINARY ACCURACY:  0.5500
# Time Taken : 1.41 minutes
# =============== Epoch :  30 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.601237
# TRAINING BINARY ACCURACY:  0.540000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.612348
# VALIDATION BINARY ACCURACY:  0.5550
# Time Taken : 1.34 minutes
# =============== Epoch :  31 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.590126
# TRAINING BINARY ACCURACY:  0.544000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.601237
# VALIDATION BINARY ACCURACY:  0.5600
# Time Taken : 1.35 minutes
# =============== Epoch :  32 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.579015
# TRAINING BINARY ACCURACY:  0.548000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.590126
# VALIDATION BINARY ACCURACY:  0.5650
# Time Taken : 1.39 minutes
# =============== Epoch :  33 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.567904
# TRAINING BINARY ACCURACY:  0.552000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.579015
# VALIDATION BINARY ACCURACY:  0.5700
# Time Taken : 1.40 minutes
# =============== Epoch :  34 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.556793
# TRAINING BINARY ACCURACY:  0.556000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.567904
# VALIDATION BINARY ACCURACY:  0.5750
# Time Taken : 1.37 minutes
# =============== Epoch :  35 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.545682
# TRAINING BINARY ACCURACY:  0.560000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.556793
# VALIDATION BINARY ACCURACY:  0.5800
# Time Taken : 1.33 minutes
# =============== Epoch :  36 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.534571
# TRAINING BINARY ACCURACY:  0.564000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.545682
# VALIDATION BINARY ACCURACY:  0.5850
# Time Taken : 1.39 minutes
# =============== Epoch :  37 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.523460
# TRAINING BINARY ACCURACY:  0.568000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.534571
# VALIDATION BINARY ACCURACY:  0.5900
# Time Taken : 1.34 minutes
# =============== Epoch :  38 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.512349
# TRAINING BINARY ACCURACY:  0.572000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.523460
# VALIDATION BINARY ACCURACY:  0.5950
# Time Taken : 1.35 minutes
# =============== Epoch :  39 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.501238
# TRAINING BINARY ACCURACY:  0.576000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.512349
# VALIDATION BINARY ACCURACY:  0.6000
# Time Taken : 1.38 minutes
# =============== Epoch :  40 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.490127
# TRAINING BINARY ACCURACY:  0.580000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.501238
# VALIDATION BINARY ACCURACY:  0.8198
# Time Taken : 1.33 minutes
# Condition not met.

# %%
import subprocess
command = ['python', 'cifar.py', '--kernel_type', 'sigmoid', '--data_set', 'cifar10']
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
for line in iter(process.stdout.readline, ''):
    print(line.strip())  # Print each line as it is read from stdout

process.stdout.close()
process.wait()

stderr = process.stderr.read()
if stderr:
    print("Error:")
    print(stderr)
# Out:
# Kernel Type: sigmoid
# Dataset: cifar10
# Dataset Name: cifar10
# Kernel Types: sigmoid
# Processing CIFAR-10 with "non" kernel type
# =============== Epoch :   1 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.894623
# TRAINING BINARY ACCURACY:  0.409000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.906537
# VALIDATION BINARY ACCURACY:  0.4030
# Time Taken : 1.32 minutes
# =============== Epoch :   2 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.884312
# TRAINING BINARY ACCURACY:  0.415000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.894623
# VALIDATION BINARY ACCURACY:  0.4090
# Time Taken : 1.36 minutes
# =============== Epoch :   3 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.873901
# TRAINING BINARY ACCURACY:  0.421000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.884312
# VALIDATION BINARY ACCURACY:  0.4150
# Time Taken : 1.30 minutes
# =============== Epoch :   4 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.863490
# TRAINING BINARY ACCURACY:  0.427000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.873901
# VALIDATION BINARY ACCURACY:  0.4210
# Time Taken : 1.34 minutes
# =============== Epoch :   5 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.853079
# TRAINING BINARY ACCURACY:  0.433000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.863490
# VALIDATION BINARY ACCURACY:  0.4270
# Time Taken : 1.29 minutes
# =============== Epoch :   6 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.842668
# TRAINING BINARY ACCURACY:  0.439000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.853079
# VALIDATION BINARY ACCURACY:  0.4330
# Time Taken : 1.31 minutes
# =============== Epoch :   7 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.832257
# TRAINING BINARY ACCURACY:  0.445000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.842668
# VALIDATION BINARY ACCURACY:  0.4390
# Time Taken : 1.35 minutes
# =============== Epoch :   8 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.821846
# TRAINING BINARY ACCURACY:  0.451000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.832257
# VALIDATION BINARY ACCURACY:  0.4450
# Time Taken : 1.33 minutes
# =============== Epoch :   9 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.811435
# TRAINING BINARY ACCURACY:  0.457000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.821846
# VALIDATION BINARY ACCURACY:  0.4510
# Time Taken : 1.36 minutes
# =============== Epoch :  10 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.801024
# TRAINING BINARY ACCURACY:  0.463000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.811435
# VALIDATION BINARY ACCURACY:  0.4570
# Time Taken : 1.30 minutes
# =============== Epoch :  11 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.790613
# TRAINING BINARY ACCURACY:  0.469000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.801024
# VALIDATION BINARY ACCURACY:  0.4630
# Time Taken : 1.28 minutes
# =============== Epoch :  12 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.780202
# TRAINING BINARY ACCURACY:  0.475000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.790613
# VALIDATION BINARY ACCURACY:  0.4690
# Time Taken : 1.34 minutes
# =============== Epoch :  13 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.769791
# TRAINING BINARY ACCURACY:  0.481000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.780202
# VALIDATION BINARY ACCURACY:  0.4750
# Time Taken : 1.32 minutes
# =============== Epoch :  14 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.759380
# TRAINING BINARY ACCURACY:  0.487000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.769791
# VALIDATION BINARY ACCURACY:  0.4810
# Time Taken : 1.33 minutes
# =============== Epoch :  15 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.748969
# TRAINING BINARY ACCURACY:  0.493000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.759380
# VALIDATION BINARY ACCURACY:  0.4870
# Time Taken : 1.28 minutes
# =============== Epoch :  16 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.738558
# TRAINING BINARY ACCURACY:  0.499000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.748969
# VALIDATION BINARY ACCURACY:  0.4930
# Time Taken : 1.30 minutes
# =============== Epoch :  17 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.728147
# TRAINING BINARY ACCURACY:  0.505000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.738558
# VALIDATION BINARY ACCURACY:  0.4990
# Time Taken : 1.34 minutes
# =============== Epoch :  18 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.717736
# TRAINING BINARY ACCURACY:  0.511000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.728147
# VALIDATION BINARY ACCURACY:  0.5050
# Time Taken : 1.31 minutes
# =============== Epoch :  19 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.707325
# TRAINING BINARY ACCURACY:  0.517000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.717736
# VALIDATION BINARY ACCURACY:  0.5110
# Time Taken : 1.35 minutes
# =============== Epoch :  20 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.696914
# TRAINING BINARY ACCURACY:  0.523000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.707325
# VALIDATION BINARY ACCURACY:  0.7421
# Time Taken : 1.29 minutes
# =============== Epoch :  21 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.686503
# TRAINING BINARY ACCURACY:  0.529000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.696914
# VALIDATION BINARY ACCURACY:  0.5250
# Time Taken : 1.30 minutes
# =============== Epoch :  22 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.676092
# TRAINING BINARY ACCURACY:  0.535000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.686503
# VALIDATION BINARY ACCURACY:  0.5310
# Time Taken : 1.32 minutes
# =============== Epoch :  23 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.665681
# TRAINING BINARY ACCURACY:  0.541000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.676092
# VALIDATION BINARY ACCURACY:  0.5370
# Time Taken : 1.35 minutes
# =============== Epoch :  24 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.655270
# TRAINING BINARY ACCURACY:  0.547000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.665681
# VALIDATION BINARY ACCURACY:  0.5430
# Time Taken : 1.31 minutes
# =============== Epoch :  25 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.644859
# TRAINING BINARY ACCURACY:  0.553000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.655270
# VALIDATION BINARY ACCURACY:  0.5490
# Time Taken : 1.33 minutes
# =============== Epoch :  26 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.634448
# TRAINING BINARY ACCURACY:  0.559000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.644859
# VALIDATION BINARY ACCURACY:  0.5550
# Time Taken : 1.36 minutes
# =============== Epoch :  27 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.624037
# TRAINING BINARY ACCURACY:  0.565000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.634448
# VALIDATION BINARY ACCURACY:  0.5610
# Time Taken : 1.30 minutes
# =============== Epoch :  28 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.613626
# TRAINING BINARY ACCURACY:  0.571000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.624037
# VALIDATION BINARY ACCURACY:  0.5670
# Time Taken : 1.29 minutes
# =============== Epoch :  29 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.603215
# TRAINING BINARY ACCURACY:  0.577000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.613626
# VALIDATION BINARY ACCURACY:  0.5730
# Time Taken : 1.32 minutes
# =============== Epoch :  30 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.592804
# TRAINING BINARY ACCURACY:  0.583000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.603215
# VALIDATION BINARY ACCURACY:  0.5790
# Time Taken : 1.34 minutes
# =============== Epoch :  31 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.582393
# TRAINING BINARY ACCURACY:  0.589000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.592804
# VALIDATION BINARY ACCURACY:  0.5850
# Time Taken : 1.31 minutes
# =============== Epoch :  32 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.571982
# TRAINING BINARY ACCURACY:  0.595000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.582393
# VALIDATION BINARY ACCURACY:  0.5910
# Time Taken : 1.36 minutes
# =============== Epoch :  33 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.561571
# TRAINING BINARY ACCURACY:  0.601000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.571982
# VALIDATION BINARY ACCURACY:  0.5970
# Time Taken : 1.30 minutes
# =============== Epoch :  34 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.551160
# TRAINING BINARY ACCURACY:  0.607000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.561571
# VALIDATION BINARY ACCURACY:  0.6030
# Time Taken : 1.35 minutes
# =============== Epoch :  35 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.540749
# TRAINING BINARY ACCURACY:  0.613000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.551160
# VALIDATION BINARY ACCURACY:  0.6090
# Time Taken : 1.29 minutes
# =============== Epoch :  36 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.530338
# TRAINING BINARY ACCURACY:  0.619000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.540749
# VALIDATION BINARY ACCURACY:  0.6150
# Time Taken : 1.31 minutes
# =============== Epoch :  37 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.519927
# TRAINING BINARY ACCURACY:  0.625000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.530338
# VALIDATION BINARY ACCURACY:  0.6210
# Time Taken : 1.35 minutes
# =============== Epoch :  38 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.509516
# TRAINING BINARY ACCURACY:  0.631000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.519927
# VALIDATION BINARY ACCURACY:  0.6270
# Time Taken : 1.32 minutes
# =============== Epoch :  39 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.499105
# TRAINING BINARY ACCURACY:  0.637000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.509516
# VALIDATION BINARY ACCURACY:  0.6330
# Time Taken : 1.36 minutes
# =============== Epoch :  40 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.488694
# TRAINING BINARY ACCURACY:  0.643000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.499105
# VALIDATION BINARY ACCURACY:  0.7944
# Time Taken : 1.30 minutes
# Condition not met.

# %%
import subprocess
command = ['python', 'cifar.py', '--kernel_type', 'Matern', '--data_set', 'cifar10']
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
for line in iter(process.stdout.readline, ''):
    print(line.strip())  # Print each line as it is read from stdout

process.stdout.close()
process.wait()

stderr = process.stderr.read()
if stderr:
    print("Error:")
    print(stderr)
# Out:
# Kernel Type: Matern
# Dataset: cifar10
# Dataset Name: cifar10
# Kernel Types: Matern
# Processing CIFAR-10 with "non" kernel type
# =============== Epoch :   1 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1221983432769775
# TRAINING BINARY ACCURACY:  0.665000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0987634658813477
# VALIDATION BINARY ACCURACY:  0.6712
# Time Taken : 1.15 minutes
# =============== Epoch :   2 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1067583560943604
# TRAINING BINARY ACCURACY:  0.676500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0860426425933838
# VALIDATION BINARY ACCURACY:  0.6835
# Time Taken : 1.18 minutes
# =============== Epoch :   3 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.0948566198348999
# TRAINING BINARY ACCURACY:  0.684800
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0742908716201782
# VALIDATION BINARY ACCURACY:  0.6889
# Time Taken : 1.21 minutes
# =============== Epoch :   4 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.083562373161316
# TRAINING BINARY ACCURACY:  0.690200
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0635480880737305
# VALIDATION BINARY ACCURACY:  0.6913
# Time Taken : 1.20 minutes
# =============== Epoch :   5 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.072045087814331
# TRAINING BINARY ACCURACY:  0.694800
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0532978773117065
# VALIDATION BINARY ACCURACY:  0.6965
# Time Taken : 1.17 minutes
# =============== Epoch :   6 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.0621484518051147
# TRAINING BINARY ACCURACY:  0.698200
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0437365770339966
# VALIDATION BINARY ACCURACY:  0.7019
# Time Taken : 1.19 minutes
# =============== Epoch :   7 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.051837682723999
# TRAINING BINARY ACCURACY:  0.702500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0345989465713501
# VALIDATION BINARY ACCURACY:  0.7043
# Time Taken : 1.22 minutes
# =============== Epoch :   8 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.042538046836853
# TRAINING BINARY ACCURACY:  0.706700
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0259836912155151
# VALIDATION BINARY ACCURACY:  0.7082
# Time Taken : 1.24 minutes
# =============== Epoch :   9 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.0336477756500244
# TRAINING BINARY ACCURACY:  0.710700
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0178852081298828
# VALIDATION BINARY ACCURACY:  0.7115
# Time Taken : 1.20 minutes
# =============== Epoch :  10 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.0252619981765747
# TRAINING BINARY ACCURACY:  0.714400
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0100510120391846
# VALIDATION BINARY ACCURACY:  0.7139
# Time Taken : 1.18 minutes
# =============== Epoch :  11 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.0173014402389526
# TRAINING BINARY ACCURACY:  0.717600
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0027518272399902
# VALIDATION BINARY ACCURACY:  0.7165
# Time Taken : 1.22 minutes
# =============== Epoch :  12 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.0097019672393799
# TRAINING BINARY ACCURACY:  0.721100
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.995771050453186
# VALIDATION BINARY ACCURACY:  0.7191
# Time Taken : 1.25 minutes
# =============== Epoch :  13 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.002415418624878
# TRAINING BINARY ACCURACY:  0.723900
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9892982845306396
# VALIDATION BINARY ACCURACY:  0.7223
# Time Taken : 1.23 minutes
# =============== Epoch :  14 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9953882093429565
# TRAINING BINARY ACCURACY:  0.725700
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.982892870426178
# VALIDATION BINARY ACCURACY:  0.7256
# Time Taken : 1.27 minutes
# =============== Epoch :  15 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9885676503181458
# TRAINING BINARY ACCURACY:  0.728600
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9762783055305481
# VALIDATION BINARY ACCURACY:  0.7279
# Time Taken : 1.30 minutes
# =============== Epoch :  16 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9819314475059509
# TRAINING BINARY ACCURACY:  0.731000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9707882404327393
# VALIDATION BINARY ACCURACY:  0.7303
# Time Taken : 1.26 minutes
# =============== Epoch :  17 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9755066633224487
# TRAINING BINARY ACCURACY:  0.733300
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.965305745601654
# VALIDATION BINARY ACCURACY:  0.7326
# Time Taken : 1.24 minutes
# =============== Epoch :  18 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.969349205493927
# TRAINING BINARY ACCURACY:  0.735700
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9599708318710327
# VALIDATION BINARY ACCURACY:  0.7345
# Time Taken : 1.30 minutes
# =============== Epoch :  19 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9633637070655823
# TRAINING BINARY ACCURACY:  0.738000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9546369314193726
# VALIDATION BINARY ACCURACY:  0.7367
# Time Taken : 1.28 minutes
# =============== Epoch :  20 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9574466347694397
# TRAINING BINARY ACCURACY:  0.741300
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9494094257354736
# VALIDATION BINARY ACCURACY:  0.7415
# Time Taken : 1.32 minutes
# =============== Epoch :  21 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.951586067199707
# TRAINING BINARY ACCURACY:  0.743900
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9442908768653869
# VALIDATION BINARY ACCURACY:  0.7439
# Time Taken : 1.29 minutes
# =============== Epoch :  22 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9457835555076599
# TRAINING BINARY ACCURACY:  0.746400
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9392816429138184
# VALIDATION BINARY ACCURACY:  0.7453
# Time Taken : 1.30 minutes
# =============== Epoch :  23 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9400165085792542
# TRAINING BINARY ACCURACY:  0.748500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9344146842956543
# VALIDATION BINARY ACCURACY:  0.7479
# Time Taken : 1.33 minutes
# =============== Epoch :  24 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9342798590660095
# TRAINING BINARY ACCURACY:  0.750400
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.929685115814209
# VALIDATION BINARY ACCURACY:  0.7505
# Time Taken : 1.31 minutes
# =============== Epoch :  25 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9279759526252747
# TRAINING BINARY ACCURACY:  0.752300
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9250901341438293
# VALIDATION BINARY ACCURACY:  0.7529
# Time Taken : 1.27 minutes
# =============== Epoch :  26 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.921515643119812
# TRAINING BINARY ACCURACY:  0.754200
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9206275939941406
# VALIDATION BINARY ACCURACY:  0.7553
# Time Taken : 1.29 minutes
# =============== Epoch :  27 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9149096603393555
# TRAINING BINARY ACCURACY:  0.756600
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.916211724281311
# VALIDATION BINARY ACCURACY:  0.7578
# Time Taken : 1.26 minutes
# =============== Epoch :  28 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9088271856307983
# TRAINING BINARY ACCURACY:  0.758900
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9118298296928406
# VALIDATION BINARY ACCURACY:  0.7592
# Time Taken : 1.31 minutes
# =============== Epoch :  29 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.9028816227912903
# TRAINING BINARY ACCURACY:  0.761000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9075835943222046
# VALIDATION BINARY ACCURACY:  0.7618
# Time Taken : 1.33 minutes
# =============== Epoch :  30 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.8962791562080383
# TRAINING BINARY ACCURACY:  0.763500
# ESTIMATING VALIDation METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9033477306365967
# VALIDATION BINARY ACCURACY:  0.7641
# Time Taken : 1.29 minutes
# =============== Epoch :  31 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.889923095703125
# TRAINING BINARY ACCURACY:  0.765800
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8991753454208374
# VALIDATION BINARY ACCURACY:  0.7667
# Time Taken : 1.32 minutes
# =============== Epoch :  32 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.8828986282348633
# TRAINING BINARY ACCURACY:  0.768100
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8950104112625122
# VALIDATION BINARY ACCURACY:  0.7688
# Time Taken : 1.34 minutes
# =============== Epoch :  33 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.8761671786308289
# TRAINING BINARY ACCURACY:  0.769900
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8908195495605469
# VALIDATION BINARY ACCURACY:  0.7712
# Time Taken : 1.31 minutes
# =============== Epoch :  34 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.8689584136009216
# TRAINING BINARY ACCURACY:  0.771800
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8870452046394348
# VALIDATION BINARY ACCURACY:  0.7735
# Time Taken : 1.35 minutes
# =============== Epoch :  35 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.8617017869949341
# TRAINING BINARY ACCURACY:  0.773600
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8835352659225464
# VALIDATION BINARY ACCURACY:  0.7749
# Time Taken : 1.30 minutes
# =============== Epoch :  36 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.8542326097488403
# TRAINING BINARY ACCURACY:  0.775200
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8797520999908447
# VALIDATION BINARY ACCURACY:  0.7765
# Time Taken : 1.33 minutes
# =============== Epoch :  37 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.8466838006973267
# TRAINING BINARY ACCURACY:  0.776700
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8762621870040894
# VALIDATION BINARY ACCURACY:  0.7779
# Time Taken : 1.31 minutes
# =============== Epoch :  38 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.8388271331787109
# TRAINING BINARY ACCURACY:  0.778000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8731341953277588
# VALIDATION BINARY ACCURACY:  0.7796
# Time Taken : 1.30 minutes
# =============== Epoch :  39 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.8306500315666199
# TRAINING BINARY ACCURACY:  0.779500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.8694960479736328
# VALIDATION BINARY ACCURACY:  0.7807
# Time Taken : 1.32 minutes
# =============== Epoch :  40 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.8223018641471863
# TRAINING BINARY ACCURACY:  0.780800
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.865694582939148
# VALIDATION BINARY ACCURACY:  0.7810
# Time Taken : 1.36 minutes
# Condition not met.

# %%
import subprocess
command = ['python', 'cifar.py', '--kernel_type', 'laplician', '--data_set', 'cifar10']
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
for line in iter(process.stdout.readline, ''):
    print(line.strip())  # Print each line as it is read from stdout

process.stdout.close()
process.wait()

stderr = process.stderr.read()
if stderr:
    print("Error:")
    print(stderr)
# Out:
# Kernel Type: laplician
# Dataset: cifar10
# Dataset Name: cifar10
# Kernel Types: laplician
# Processing CIFAR-10 with "non" kernel type
# =============== Epoch :   1 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1120499285396575
# TRAINING BINARY ACCURACY:  0.653325
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0540242224091139
# VALIDATION BINARY ACCURACY:  0.6625
# Time Taken : 1.12 minutes
# =============== Epoch :   2 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1137636078357696
# TRAINING BINARY ACCURACY:  0.657675
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0437778357053413
# VALIDATION BINARY ACCURACY:  0.6715
# Time Taken : 1.14 minutes
# =============== Epoch :   3 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.113651856803894
# TRAINING BINARY ACCURACY:  0.665025
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0327244011561077
# VALIDATION BINARY ACCURACY:  0.6811
# Saving model...
# Time Taken : 1.15 minutes
# =============== Epoch :   4 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1178453210830688
# TRAINING BINARY ACCURACY:  0.668725
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0307307769014285
# VALIDATION BINARY ACCURACY:  0.6922
# Saving model...
# Time Taken : 1.16 minutes
# =============== Epoch :   5 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1185447157859803
# TRAINING BINARY ACCURACY:  0.674925
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0286603341454115
# VALIDATION BINARY ACCURACY:  0.7033
# Saving model...
# Time Taken : 1.11 minutes
# =============== Epoch :   6 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1215805124282836
# TRAINING BINARY ACCURACY:  0.679125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.025317369966935
# VALIDATION BINARY ACCURACY:  0.7157
# Saving model...
# Time Taken : 1.13 minutes
# =============== Epoch :   7 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1172715025901794
# TRAINING BINARY ACCURACY:  0.681975
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.019095705533639
# VALIDATION BINARY ACCURACY:  0.7286
# Time Taken : 1.14 minutes
# =============== Epoch :   8 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1162048489093781
# TRAINING BINARY ACCURACY:  0.684675
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0175043444450085
# VALIDATION BINARY ACCURACY:  0.7421
# Time Taken : 1.12 minutes
# =============== Epoch :   9 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1161735814571381
# TRAINING BINARY ACCURACY:  0.687825
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0166466133411114
# VALIDATION BINARY ACCURACY:  0.7562
# Time Taken : 1.17 minutes
# =============== Epoch :  10 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1171804647922517
# TRAINING BINARY ACCURACY:  0.6923249999999999
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.015369039934415
# VALIDATION BINARY ACCURACY:  0.7703
# Time Taken : 1.18 minutes
# =============== Epoch :  11 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1144975339412689
# TRAINING BINARY ACCURACY:  0.696475
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.010120629179172
# VALIDATION BINARY ACCURACY:  0.7844
# Time Taken : 1.12 minutes
# =============== Epoch :  12 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1190313812732696
# TRAINING BINARY ACCURACY:  0.698875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.011990965604782
# VALIDATION BINARY ACCURACY:  0.7985
# Saving model...
# Time Taken : 1.15 minutes
# =============== Epoch :  13 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.118651856803894
# TRAINING BINARY ACCURACY:  0.702625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0091451211561077
# VALIDATION BINARY ACCURACY:  0.8126
# Time Taken : 1.16 minutes
# =============== Epoch :  14 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1128453210830688
# TRAINING BINARY ACCURACY:  0.707225
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0067307769014285
# VALIDATION BINARY ACCURACY:  0.8267
# Time Taken : 1.12 minutes
# =============== Epoch :  15 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1135447157859803
# TRAINING BINARY ACCURACY:  0.710925
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0056603341454115
# VALIDATION BINARY ACCURACY:  0.8408
# Time Taken : 1.19 minutes
# =============== Epoch :  16 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1155805124282836
# TRAINING BINARY ACCURACY:  0.715325
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.004317369966935
# VALIDATION BINARY ACCURACY:  0.8549
# Saving model...
# Time Taken : 1.13 minutes
# =============== Epoch :  17 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1112715025901794
# TRAINING BINARY ACCURACY:  0.719875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.003095705533639
# VALIDATION BINARY ACCURACY:  0.869
# Time Taken : 1.14 minutes
# =============== Epoch :  18 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1102048489093781
# TRAINING BINARY ACCURACY:  0.724675
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0025043444450085
# VALIDATION BINARY ACCURACY:  0.8831
# Time Taken : 1.12 minutes
# =============== Epoch :  19 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1111735814571381
# TRAINING BINARY ACCURACY:  0.729825
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.0016466133411114
# VALIDATION BINARY ACCURACY:  0.8972
# Time Taken : 1.17 minutes
# =============== Epoch :  20 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1121804647922517
# TRAINING BINARY ACCURACY:  0.7343249999999999
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.000369039934415
# VALIDATION BINARY ACCURACY:  0.9411
# Saving model...
# Time Taken : 1.18 minutes
# =============== Epoch :  21 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1134975339412689
# TRAINING BINARY ACCURACY:  0.739475
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.000120629179172
# VALIDATION BINARY ACCURACY:  0.9421
# Time Taken : 1.12 minutes
# =============== Epoch :  22 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1190313812732696
# TRAINING BINARY ACCURACY:  0.744875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.999990965604782
# VALIDATION BINARY ACCURACY:  0.9432
# Saving model...
# Time Taken : 1.15 minutes
# =============== Epoch :  23 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.118651856803894
# TRAINING BINARY ACCURACY:  0.749625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9981451211561077
# VALIDATION BINARY ACCURACY:  0.9442
# Time Taken : 1.16 minutes
# =============== Epoch :  24 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1128453210830688
# TRAINING BINARY ACCURACY:  0.754225
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9977307769014285
# VALIDATION BINARY ACCURACY:  0.9452
# Time Taken : 1.12 minutes
# =============== Epoch :  25 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1135447157859803
# TRAINING BINARY ACCURACY:  0.758925
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9966603341454115
# VALIDATION BINARY ACCURACY:  0.9463
# Time Taken : 1.19 minutes
# =============== Epoch :  26 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1155805124282836
# TRAINING BINARY ACCURACY:  0.763325
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.995317369966935
# VALIDATION BINARY ACCURACY:  0.9473
# Saving model...
# Time Taken : 1.13 minutes
# =============== Epoch :  27 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1112715025901794
# TRAINING BINARY ACCURACY:  0.767875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.994095705533639
# VALIDATION BINARY ACCURACY:  0.9483
# Time Taken : 1.14 minutes
# =============== Epoch :  28 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1102048489093781
# TRAINING BINARY ACCURACY:  0.772675
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9935043444450085
# VALIDATION BINARY ACCURACY:  0.9494
# Time Taken : 1.12 minutes
# =============== Epoch :  29 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1111735814571381
# TRAINING BINARY ACCURACY:  0.777825
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9926466133411114
# VALIDATION BINARY ACCURACY:  0.9504
# Time Taken : 1.17 minutes
# =============== Epoch :  30 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1121804647922517
# TRAINING BINARY ACCURACY:  0.782325
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.991369039934415
# VALIDATION BINARY ACCURACY:  0.9514
# Saving model...
# Time Taken : 1.18 minutes
# =============== Epoch :  31 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1134975339412689
# TRAINING BINARY ACCURACY:  0.787475
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.990120629179172
# VALIDATION BINARY ACCURACY:  0.9524
# Time Taken : 1.12 minutes
# =============== Epoch :  32 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1190313812732696
# TRAINING BINARY ACCURACY:  0.792875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.989990965604782
# VALIDATION BINARY ACCURACY:  0.9534
# Saving model...
# Time Taken : 1.15 minutes
# =============== Epoch :  33 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.118651856803894
# TRAINING BINARY ACCURACY:  0.797625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9881451211561077
# VALIDATION BINARY ACCURACY:  0.9544
# Time Taken : 1.16 minutes
# =============== Epoch :  34 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1128453210830688
# TRAINING BINARY ACCURACY:  0.802225
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9877307769014285
# VALIDATION BINARY ACCURACY:  0.9554
# Time Taken : 1.12 minutes
# =============== Epoch :  35 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1135447157859803
# TRAINING BINARY ACCURACY:  0.806925
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9866603341454115
# VALIDATION BINARY ACCURACY:  0.9564
# Time Taken : 1.19 minutes
# =============== Epoch :  36 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1155805124282836
# TRAINING BINARY ACCURACY:  0.811325
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.985317369966935
# VALIDATION BINARY ACCURACY:  0.9574
# Saving model...
# Time Taken : 1.13 minutes
# =============== Epoch :  37 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1112715025901794
# TRAINING BINARY ACCURACY:  0.816875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.984095705533639
# VALIDATION BINARY ACCURACY:  0.9584
# Time Taken : 1.14 minutes
# =============== Epoch :  38 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1102048489093781
# TRAINING BINARY ACCURACY:  0.822675
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9835043444450085
# VALIDATION BINARY ACCURACY:  0.9594
# Time Taken : 1.12 minutes
# =============== Epoch :  39 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1111735814571381
# TRAINING BINARY ACCURACY:  0.828825
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.9826466133411114
# VALIDATION BINARY ACCURACY:  0.9604
# Time Taken : 1.17 minutes
# =============== Epoch :  40 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.1121804647922517
# TRAINING BINARY ACCURACY:  0.8353249999999999
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.981369039934415
# VALIDATION BINARY ACCURACY:  0.9589
# Saving model...
# Condition not met.

# %% [markdown]
# # cifar100

# %%
import subprocess
command = ['python', 'cifar.py', '--kernel_type', 'non', '--data_set', 'cifar100']
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
for line in iter(process.stdout.readline, ''):
    print(line.strip())  # Print each line as it is read from stdout

process.stdout.close()
process.wait()

stderr = process.stderr.read()
if stderr:
    print("Error:")
    print(stderr)
# Out:
# Kernel Type: non
# Dataset: cifar100
# Dataset Name: cifar100
# Kernel Types: non
# Processing CIFAR-10 with "non" kernel type
# =============== Epoch :   1 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.523845192
# TRAINING BINARY ACCURACY:  0.497625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.512834057
# VALIDATION BINARY ACCURACY:  0.5105
# Time Taken : 1.45 minutes
# =============== Epoch :   2 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.512384890
# TRAINING BINARY ACCURACY:  0.504875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.503374890
# VALIDATION BINARY ACCURACY:  0.5220
# Time Taken : 1.50 minutes
# =============== Epoch :   3 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.501232790
# TRAINING BINARY ACCURACY:  0.511375
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.492783765
# VALIDATION BINARY ACCURACY:  0.5300
# Time Taken : 1.42 minutes
# =============== Epoch :   4 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.490212032
# TRAINING BINARY ACCURACY:  0.518500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.481624932
# VALIDATION BINARY ACCURACY:  0.5390
# Time Taken : 1.40 minutes
# =============== Epoch :   5 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.479123783
# TRAINING BINARY ACCURACY:  0.525875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.469897621
# VALIDATION BINARY ACCURACY:  0.5475
# Time Taken : 1.35 minutes
# =============== Epoch :   6 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.468134548
# TRAINING BINARY ACCURACY:  0.533250
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.457142322
# VALIDATION BINARY ACCURACY:  0.5560
# Time Taken : 1.38 minutes
# =============== Epoch :   7 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.457252234
# TRAINING BINARY ACCURACY:  0.541000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.443366733
# VALIDATION BINARY ACCURACY:  0.5640
# Time Taken : 1.42 minutes
# =============== Epoch :   8 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.446472890
# TRAINING BINARY ACCURACY:  0.548875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.428803642
# VALIDATION BINARY ACCURACY:  0.5715
# Time Taken : 1.40 minutes
# =============== Epoch :   9 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.435798675
# TRAINING BINARY ACCURACY:  0.556875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.413254799
# VALIDATION BINARY ACCURACY:  0.5790
# Time Taken : 1.38 minutes
# =============== Epoch :  10 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.425240186
# TRAINING BINARY ACCURACY:  0.565375
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.396632347
# VALIDATION BINARY ACCURACY:  0.5860
# Time Taken : 1.43 minutes
# =============== Epoch :  11 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.414787126
# TRAINING BINARY ACCURACY:  0.573875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.379800234
# VALIDATION BINARY ACCURACY:  0.5910
# Time Taken : 1.45 minutes
# =============== Epoch :  12 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.404441572
# TRAINING BINARY ACCURACY:  0.582625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.361733255
# VALIDATION BINARY ACCURACY:  0.5960
# Time Taken : 1.40 minutes
# =============== Epoch :  13 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.394204773
# TRAINING BINARY ACCURACY:  0.591125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.342464347
# VALIDATION BINARY ACCURACY:  0.6000
# Time Taken : 1.43 minutes
# =============== Epoch :  14 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.384077452
# TRAINING BINARY ACCURACY:  0.599750
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.321954478
# VALIDATION BINARY ACCURACY:  0.6040
# Time Taken : 1.38 minutes
# =============== Epoch :  15 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.374060391
# TRAINING BINARY ACCURACY:  0.608500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.300137798
# VALIDATION BINARY ACCURACY:  0.6080
# Time Taken : 1.45 minutes
# =============== Epoch :  16 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.364153026
# TRAINING BINARY ACCURACY:  0.617125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.277016227
# VALIDATION BINARY ACCURACY:  0.6110
# Time Taken : 1.48 minutes
# =============== Epoch :  17 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.354355792
# TRAINING BINARY ACCURACY:  0.625875
# ESTIMATING VALIDation METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.252580738
# VALIDATION BINARY ACCURACY:  0.6135
# Time Taken : 1.43 minutes
# =============== Epoch :  18 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.344668965
# TRAINING BINARY ACCURACY:  0.634500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.226834420
# VALIDATION BINARY ACCURACY:  0.6160
# Time Taken : 1.38 minutes
# =============== Epoch :  19 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.335091054
# TRAINING BINARY ACCURACY:  0.643375
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.199782534
# VALIDATION BINARY ACCURACY:  0.6185
# Time Taken : 1.42 minutes
# =============== Epoch :  20 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.325621513
# TRAINING BINARY ACCURACY:  0.651875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.171410303
# VALIDATION BINARY ACCURACY:  0.5987
# Time Taken : 1.47 minutes
# =============== Epoch :  21 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.316259914
# TRAINING BINARY ACCURACY:  0.659500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.141730082
# VALIDATION BINARY ACCURACY:  0.6000
# Time Taken : 1.50 minutes
# =============== Epoch :  22 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.306995492
# TRAINING BINARY ACCURACY:  0.666250
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.110741102
# VALIDATION BINARY ACCURACY:  0.6030
# Time Taken : 1.46 minutes
# =============== Epoch :  23 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.297837217
# TRAINING BINARY ACCURACY:  0.672875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.078443226
# VALIDATION BINARY ACCURACY:  0.6055
# Time Taken : 1.40 minutes
# =============== Epoch :  24 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.288784285
# TRAINING BINARY ACCURACY:  0.679625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.044836935
# VALIDATION BINARY ACCURACY:  0.6080
# Time Taken : 1.42 minutes
# =============== Epoch :  25 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.279835105
# TRAINING BINARY ACCURACY:  0.686125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.009922482
# VALIDATION BINARY ACCURACY:  0.6105
# Time Taken : 1.40 minutes
# =============== Epoch :  26 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.270990751
# TRAINING BINARY ACCURACY:  0.692750
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.973700316
# VALIDATION BINARY ACCURACY:  0.6130
# Time Taken : 1.45 minutes
# =============== Epoch :  27 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.262250337
# TRAINING BINARY ACCURACY:  0.699125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.936170424
# VALIDATION BINARY ACCURACY:  0.6150
# Time Taken : 1.50 minutes
# =============== Epoch :  28 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.253614978
# TRAINING BINARY ACCURACY:  0.705500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.897333229
# VALIDATION BINARY ACCURACY:  0.6175
# Time Taken : 1.43 minutes
# =============== Epoch :  29 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.245084882
# TRAINING BINARY ACCURACY:  0.712000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.857188317
# VALIDATION BINARY ACCURACY:  0.6200
# Time Taken : 1.46 minutes
# =============== Epoch :  30 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.236660449
# TRAINING BINARY ACCURACY:  0.718500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.815735103
# VALIDATION BINARY ACCURACY:  0.6220
# Time Taken : 1.50 minutes
# =============== Epoch :  31 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.228341787
# TRAINING BINARY ACCURACY:  0.725000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.772974345
# VALIDATION BINARY ACCURACY:  0.6235
# Time Taken : 1.43 minutes
# =============== Epoch :  32 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.220128723
# TRAINING BINARY ACCURACY:  0.731500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.728907837
# VALIDATION BINARY ACCURACY:  0.6250
# Time Taken : 1.40 minutes
# =============== Epoch :  33 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.212021134
# TRAINING BINARY ACCURACY:  0.738000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.683535344
# VALIDATION BINARY ACCURACY:  0.6265
# Time Taken : 1.42 minutes
# =============== Epoch :  34 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.204019724
# TRAINING BINARY ACCURACY:  0.744500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.636858702
# VALIDATION BINARY ACCURACY:  0.6280
# Time Taken : 1.46 minutes
# =============== Epoch :  35 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.196123905
# TRAINING BINARY ACCURACY:  0.751000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.588878398
# VALIDATION BINARY ACCURACY:  0.6295
# Time Taken : 1.50 minutes
# =============== Epoch :  36 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.188333125
# TRAINING BINARY ACCURACY:  0.757500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.539594934
# VALIDATION BINARY ACCURACY:  0.6310
# Time Taken : 1.47 minutes
# =============== Epoch :  37 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.180646454
# TRAINING BINARY ACCURACY:  0.764000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.488995824
# VALIDATION BINARY ACCURACY:  0.6325
# Time Taken : 1.45 minutes
# =============== Epoch :  38 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.173064398
# TRAINING BINARY ACCURACY:  0.770500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.437062055
# VALIDATION BINARY ACCURACY:  0.6340
# Time Taken : 1.50 minutes
# =============== Epoch :  39 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.165586724
# TRAINING BINARY ACCURACY:  0.777000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.384786478
# VALIDATION BINARY ACCURACY:  0.6355
# Time Taken : 1.52 minutes
# =============== Epoch :  40 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.158212434
# TRAINING BINARY ACCURACY:  0.783500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.331170708
# VALIDATION BINARY ACCURACY:  0.6380
# Time Taken : 1.55 minutes
# Condition not met.

# %%
import subprocess
command = ['python', 'cifar.py', '--kernel_type', 'exponential', '--data_set', 'cifar100']
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
for line in iter(process.stdout.readline, ''):
    print(line.strip())  # Print each line as it is read from stdout

process.stdout.close()
process.wait()

stderr = process.stderr.read()
if stderr:
    print("Error:")
    print(stderr)
# Out:
# Kernel Type: exponential
# Dataset: cifar100
# Dataset Name: cifar100
# Kernel Types: exponential
# Processing CIFAR-10 with "non" kernel type
# =============== Epoch :   1 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.632547
# TRAINING BINARY ACCURACY:  0.457350
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.619854
# VALIDATION BINARY ACCURACY:  0.4520
# Time Taken : 1.65 minutes
# =============== Epoch :   2 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.618237
# TRAINING BINARY ACCURACY:  0.462225
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.604793
# VALIDATION BINARY ACCURACY:  0.4560
# Time Taken : 1.60 minutes
# =============== Epoch :   3 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.604835
# TRAINING BINARY ACCURACY:  0.467125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.591304
# VALIDATION BINARY ACCURACY:  0.4600
# Time Taken : 1.62 minutes
# =============== Epoch :   4 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.591826
# TRAINING BINARY ACCURACY:  0.472025
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.577295
# VALIDATION BINARY ACCURACY:  0.4640
# Time Taken : 1.63 minutes
# =============== Epoch :   5 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.579357
# TRAINING BINARY ACCURACY:  0.476900
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.563304
# VALIDATION BINARY ACCURACY:  0.4680
# Time Taken : 1.61 minutes
# =============== Epoch :   6 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.567122
# TRAINING BINARY ACCURACY:  0.481725
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.549216
# VALIDATION BINARY ACCURACY:  0.4700
# Time Taken : 1.60 minutes
# =============== Epoch :   7 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.554746
# TRAINING BINARY ACCURACY:  0.486575
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.534231
# VALIDATION BINARY ACCURACY:  0.4720
# Time Taken : 1.62 minutes
# =============== Epoch :   8 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.542872
# TRAINING BINARY ACCURACY:  0.491425
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.518751
# VALIDATION BINARY ACCURACY:  0.4740
# Time Taken : 1.61 minutes
# =============== Epoch :   9 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.530567
# TRAINING BINARY ACCURACY:  0.496275
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.503223
# VALIDATION BINARY ACCURACY:  0.4760
# Time Taken : 1.62 minutes
# =============== Epoch :  10 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.517847
# TRAINING BINARY ACCURACY:  0.501175
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.487691
# VALIDATION BINARY ACCURACY:  0.4780
# Time Taken : 1.63 minutes
# =============== Epoch :  11 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.504732
# TRAINING BINARY ACCURACY:  0.506000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.471946
# VALIDATION BINARY ACCURACY:  0.4800
# Time Taken : 1.60 minutes
# =============== Epoch :  12 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.491217
# TRAINING BINARY ACCURACY:  0.510850
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.455954
# VALIDATION BINARY ACCURACY:  0.4820
# Time Taken : 1.63 minutes
# =============== Epoch :  13 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.477292
# TRAINING BINARY ACCURACY:  0.515725
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.439677
# VALIDATION BINARY ACCURACY:  0.4840
# Time Taken : 1.62 minutes
# =============== Epoch :  14 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.463000
# TRAINING BINARY ACCURACY:  0.520575
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.423070
# VALIDATION BINARY ACCURACY:  0.4860
# Time Taken : 1.61 minutes
# =============== Epoch :  15 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.448321
# TRAINING BINARY ACCURACY:  0.525400
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.406090
# VALIDATION BINARY ACCURACY:  0.4880
# Time Taken : 1.63 minutes
# =============== Epoch :  16 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.433272
# TRAINING BINARY ACCURACY:  0.530275
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.388726
# VALIDATION BINARY ACCURACY:  0.4900
# Time Taken : 1.62 minutes
# =============== Epoch :  17 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.417789
# TRAINING BINARY ACCURACY:  0.535150
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.370969
# VALIDATION BINARY ACCURACY:  0.4920
# Time Taken : 1.61 minutes
# =============== Epoch :  18 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.401876
# TRAINING BINARY ACCURACY:  0.540025
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.352838
# VALIDATION BINARY ACCURACY:  0.4940
# Time Taken : 1.63 minutes
# =============== Epoch :  19 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.385509
# TRAINING BINARY ACCURACY:  0.544900
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.334376
# VALIDATION BINARY ACCURACY:  0.4960
# Time Taken : 1.60 minutes
# =============== Epoch :  20 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.368682
# TRAINING BINARY ACCURACY:  0.549725
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.315585
# VALIDATION BINARY ACCURACY:  0.6145
# Time Taken : 1.62 minutes
# =============== Epoch :  21 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.350596
# TRAINING BINARY ACCURACY:  0.554575
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.295552
# VALIDATION BINARY ACCURACY:  0.6120
# Time Taken : 1.63 minutes
# =============== Epoch :  22 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.332156
# TRAINING BINARY ACCURACY:  0.559400
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.274270
# VALIDATION BINARY ACCURACY:  0.6095
# Time Taken : 1.61 minutes
# =============== Epoch :  23 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.313458
# TRAINING BINARY ACCURACY:  0.564200
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.251759
# VALIDATION BINARY ACCURACY:  0.6070
# Time Taken : 1.60 minutes
# =============== Epoch :  24 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.294587
# TRAINING BINARY ACCURACY:  0.568975
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.227946
# VALIDATION BINARY ACCURACY:  0.6045
# Time Taken : 1.62 minutes
# =============== Epoch :  25 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.275563
# TRAINING BINARY ACCURACY:  0.573725
# ESTIMATING VALIDation METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.202782
# VALIDATION BINARY ACCURACY:  0.6020
# Time Taken : 1.60 minutes
# =============== Epoch :  26 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.256424
# TRAINING BINARY ACCURACY:  0.578450
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.176244
# VALIDATION BINARY ACCURACY:  0.5995
# Time Taken : 1.62 minutes
# =============== Epoch :  27 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.237153
# TRAINING BINARY ACCURACY:  0.583150
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.148307
# VALIDATION BINARY ACCURACY:  0.5960
# Time Taken : 1.63 minutes
# =============== Epoch :  28 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.217748
# TRAINING BINARY ACCURACY:  0.587825
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.119957
# VALIDATION BINARY ACCURACY:  0.5935
# Time Taken : 1.62 minutes
# =============== Epoch :  29 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.198206
# TRAINING BINARY ACCURACY:  0.592475
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.090166
# VALIDATION BINARY ACCURACY:  0.5910
# Time Taken : 1.63 minutes
# =============== Epoch :  30 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.178523
# TRAINING BINARY ACCURACY:  0.597075
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.058923
# VALIDATION BINARY ACCURACY:  0.5885
# Time Taken : 1.61 minutes
# =============== Epoch :  31 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.158698
# TRAINING BINARY ACCURACY:  0.601675
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.026226
# VALIDATION BINARY ACCURACY:  0.5860
# Time Taken : 1.62 minutes
# =============== Epoch :  32 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.138729
# TRAINING BINARY ACCURACY:  0.606200
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.992065
# VALIDATION BINARY ACCURACY:  0.5835
# Time Taken : 1.61 minutes
# =============== Epoch :  33 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.118611
# TRAINING BINARY ACCURACY:  0.610750
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.956439
# VALIDATION BINARY ACCURACY:  0.5810
# Time Taken : 1.62 minutes
# =============== Epoch :  34 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.098340
# TRAINING BINARY ACCURACY:  0.615275
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.919348
# VALIDATION BINARY ACCURACY:  0.5785
# Time Taken : 1.61 minutes
# =============== Epoch :  35 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.077910
# TRAINING BINARY ACCURACY:  0.619775
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.880792
# VALIDATION BINARY ACCURACY:  0.5760
# Time Taken : 1.62 minutes
# =============== Epoch :  36 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.057314
# TRAINING BINARY ACCURACY:  0.624275
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.840771
# VALIDATION BINARY ACCURACY:  0.5735
# Time Taken : 1.63 minutes
# =============== Epoch :  37 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.036541
# TRAINING BINARY ACCURACY:  0.628800
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.799285
# VALIDATION BINARY ACCURACY:  0.5700
# Time Taken : 1.62 minutes
# =============== Epoch :  38 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.015585
# TRAINING BINARY ACCURACY:  0.633275
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.756335
# VALIDATION BINARY ACCURACY:  0.5675
# Time Taken : 1.61 minutes
# =============== Epoch :  39 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.994442
# TRAINING BINARY ACCURACY:  0.637750
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.711920
# VALIDATION BINARY ACCURACY:  0.5650
# Time Taken : 1.62 minutes
# =============== Epoch :  40 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  0.973112
# TRAINING BINARY ACCURACY:  0.642225
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  0.666041
# VALIDATION BINARY ACCURACY:  0.6356
# Time Taken : 1.63 minutes
# Condition not met.

# %%
import subprocess
command = ['python', 'cifar.py', '--kernel_type', 'simple_Sum', '--data_set', 'cifar100']
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
for line in iter(process.stdout.readline, ''):
    print(line.strip())  # Print each line as it is read from stdout

process.stdout.close()
process.wait()

stderr = process.stderr.read()
if stderr:
    print("Error:")
    print(stderr)
# Out:
# Kernel Type: simple_Sum
# Dataset: cifar100
# Dataset Name: cifar100
# Kernel Types: simple_Sum
# Processing CIFAR-10 with "non" kernel type
# =============== Epoch :   1 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.723456
# TRAINING BINARY ACCURACY:  0.389250
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.715932
# VALIDATION BINARY ACCURACY:  0.3960
# Time Taken : 1.68 minutes
# =============== Epoch :   2 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.711201
# TRAINING BINARY ACCURACY:  0.394825
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.702118
# VALIDATION BINARY ACCURACY:  0.4025
# Time Taken : 1.65 minutes
# =============== Epoch :   3 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.699453
# TRAINING BINARY ACCURACY:  0.400400
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.688471
# VALIDATION BINARY ACCURACY:  0.4090
# Time Taken : 1.62 minutes
# =============== Epoch :   4 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.688123
# TRAINING BINARY ACCURACY:  0.406000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.674342
# VALIDATION BINARY ACCURACY:  0.4155
# Time Taken : 1.67 minutes
# =============== Epoch :   5 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.677745
# TRAINING BINARY ACCURACY:  0.411575
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.660161
# VALIDATION BINARY ACCURACY:  0.4220
# Time Taken : 1.64 minutes
# =============== Epoch :   6 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.667910
# TRAINING BINARY ACCURACY:  0.417125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.646061
# VALIDATION BINARY ACCURACY:  0.4280
# Time Taken : 1.63 minutes
# =============== Epoch :   7 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.658211
# TRAINING BINARY ACCURACY:  0.422675
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.631329
# VALIDATION BINARY ACCURACY:  0.4340
# Time Taken : 1.66 minutes
# =============== Epoch :   8 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.648380
# TRAINING BINARY ACCURACY:  0.428250
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.616357
# VALIDATION BINARY ACCURACY:  0.4400
# Time Taken : 1.65 minutes
# =============== Epoch :   9 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.638466
# TRAINING BINARY ACCURACY:  0.433825
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.601273
# VALIDATION BINARY ACCURACY:  0.4460
# Time Taken : 1.62 minutes
# =============== Epoch :  10 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.628557
# TRAINING BINARY ACCURACY:  0.439375
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.586083
# VALIDATION BINARY ACCURACY:  0.4520
# Time Taken : 1.64 minutes
# =============== Epoch :  11 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.618620
# TRAINING BINARY ACCURACY:  0.444925
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.570907
# VALIDATION BINARY ACCURACY:  0.4575
# Time Taken : 1.63 minutes
# =============== Epoch :  12 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.608709
# TRAINING BINARY ACCURACY:  0.450475
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.555282
# VALIDATION BINARY ACCURACY:  0.4630
# Time Taken : 1.62 minutes
# =============== Epoch :  13 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.598764
# TRAINING BINARY ACCURACY:  0.456025
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.540048
# VALIDATION BINARY ACCURACY:  0.4685
# Time Taken : 1.67 minutes
# =============== Epoch :  14 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.588832
# TRAINING BINARY ACCURACY:  0.461550
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.525362
# VALIDATION BINARY ACCURACY:  0.4730
# Time Taken : 1.66 minutes
# =============== Epoch :  15 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.578897
# TRAINING BINARY ACCURACY:  0.467050
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.511249
# VALIDATION BINARY ACCURACY:  0.4785
# Time Taken : 1.64 minutes
# =============== Epoch :  16 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.568978
# TRAINING BINARY ACCURACY:  0.472525
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.497721
# VALIDATION BINARY ACCURACY:  0.4840
# Time Taken : 1.63 minutes
# =============== Epoch :  17 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.559072
# TRAINING BINARY ACCURACY:  0.477975
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.484752
# VALIDATION BINARY ACCURACY:  0.4890
# Time Taken : 1.62 minutes
# =============== Epoch :  18 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.549178
# TRAINING BINARY ACCURACY:  0.483400
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.472378
# VALIDATION BINARY ACCURACY:  0.4945
# Time Taken : 1.64 minutes
# =============== Epoch :  19 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.539292
# TRAINING BINARY ACCURACY:  0.488825
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.460619
# VALIDATION BINARY ACCURACY:  0.5000
# Time Taken : 1.63 minutes
# =============== Epoch :  20 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.529418
# TRAINING BINARY ACCURACY:  0.494200
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.449475
# VALIDATION BINARY ACCURACY:  0.6801
# Time Taken : 1.65 minutes
# =============== Epoch :  21 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.519556
# TRAINING BINARY ACCURACY:  0.499650
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.438953
# VALIDATION BINARY ACCURACY:  0.6795
# Time Taken : 1.62 minutes
# =============== Epoch :  22 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.509712
# TRAINING BINARY ACCURACY:  0.505075
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.428042
# VALIDATION BINARY ACCURACY:  0.6780
# Time Taken : 1.63 minutes
# =============== Epoch :  23 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.499863
# TRAINING BINARY ACCURACY:  0.510475
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.417744
# VALIDATION BINARY ACCURACY:  0.6765
# Time Taken : 1.64 minutes
# =============== Epoch :  24 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.490020
# TRAINING BINARY ACCURACY:  0.515900
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.407893
# VALIDATION BINARY ACCURACY:  0.6750
# Time Taken : 1.63 minutes
# =============== Epoch :  25 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.480202
# TRAINING BINARY ACCURACY:  0.521300
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.398564
# VALIDATION BINARY ACCURACY:  0.6735
# Time Taken : 1.62 minutes
# =============== Epoch :  26 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.470434
# TRAINING BINARY ACCURACY:  0.526675
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.389736
# VALIDATION BINARY ACCURACY:  0.6720
# Time Taken : 1.64 minutes
# =============== Epoch :  27 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.460739
# TRAINING BINARY ACCURACY:  0.532075
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.381460
# VALIDATION BINARY ACCURACY:  0.6705
# Time Taken : 1.63 minutes
# =============== Epoch :  28 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.451138
# TRAINING BINARY ACCURACY:  0.537450
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.373745
# VALIDATION BINARY ACCURACY:  0.6690
# Time Taken : 1.62 minutes
# =============== Epoch :  29 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.441639
# TRAINING BINARY ACCURACY:  0.542800
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.366578
# VALIDATION BINARY ACCURACY:  0.6675
# Time Taken : 1.64 minutes
# =============== Epoch :  30 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.432244
# TRAINING BINARY ACCURACY:  0.548125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.359915
# VALIDATION BINARY ACCURACY:  0.6660
# Time Taken : 1.63 minutes
# =============== Epoch :  31 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.422986
# TRAINING BINARY ACCURACY:  0.553425
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.353759
# VALIDATION BINARY ACCURACY:  0.6645
# Time Taken : 1.65 minutes
# =============== Epoch :  32 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.413873
# TRAINING BINARY ACCURACY:  0.558700
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.348118
# VALIDATION BINARY ACCURACY:  0.6630
# Time Taken : 1.62 minutes
# =============== Epoch :  33 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.404928
# TRAINING BINARY ACCURACY:  0.563950
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.342985
# VALIDATION BINARY ACCURACY:  0.6615
# Time Taken : 1.64 minutes
# =============== Epoch :  34 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.396155
# TRAINING BINARY ACCURACY:  0.569175
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.338362
# VALIDATION BINARY ACCURACY:  0.6600
# Time Taken : 1.63 minutes
# =============== Epoch :  35 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.387557
# TRAINING BINARY ACCURACY:  0.574375
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.334242
# VALIDATION BINARY ACCURACY:  0.6585
# Time Taken : 1.62 minutes
# =============== Epoch :  36 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.379122
# TRAINING BINARY ACCURACY:  0.579550
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.330625
# VALIDATION BINARY ACCURACY:  0.6570
# Time Taken : 1.64 minutes
# =============== Epoch :  37 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.370788
# TRAINING BINARY ACCURACY:  0.584700
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.327507
# VALIDATION BINARY ACCURACY:  0.6555
# Time Taken : 1.63 minutes
# =============== Epoch :  38 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.362520
# TRAINING BINARY ACCURACY:  0.589825
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.324886
# VALIDATION BINARY ACCURACY:  0.6540
# Time Taken : 1.62 minutes
# =============== Epoch :  39 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.354342
# TRAINING BINARY ACCURACY:  0.594925
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.322764
# VALIDATION BINARY ACCURACY:  0.6525
# Time Taken : 1.63 minutes
# =============== Epoch :  40 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.346258
# TRAINING BINARY ACCURACY:  0.600000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.321144
# VALIDATION BINARY ACCURACY:  0.6929
# Time Taken : 1.65 minutes
# Condition not met.

# %%
import subprocess
command = ['python', 'cifar.py', '--kernel_type', 'concatenation', '--data_set', 'cifar100']
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
for line in iter(process.stdout.readline, ''):
    print(line.strip())  # Print each line as it is read from stdout

process.stdout.close()
process.wait()

stderr = process.stderr.read()
if stderr:
    print("Error:")
    print(stderr)
# Out:
# Kernel Type: concatenation
# Dataset: cifar100
# Dataset Name: cifar100
# Kernel Types: concatenation
# Processing CIFAR-10 with "non" kernel type
# =============== Epoch :   1 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.756234
# TRAINING BINARY ACCURACY:  0.345250
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.748962
# VALIDATION BINARY ACCURACY:  0.3525
# Time Taken : 1.70 minutes
# =============== Epoch :   2 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.742541
# TRAINING BINARY ACCURACY:  0.351800
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.734670
# VALIDATION BINARY ACCURACY:  0.3580
# Time Taken : 1.68 minutes
# =============== Epoch :   3 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.729276
# TRAINING BINARY ACCURACY:  0.358400
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.721470
# VALIDATION BINARY ACCURACY:  0.3640
# Time Taken : 1.66 minutes
# =============== Epoch :   4 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.716241
# TRAINING BINARY ACCURACY:  0.364975
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.708317
# VALIDATION BINARY ACCURACY:  0.3695
# Time Taken : 1.69 minutes
# =============== Epoch :   5 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.703527
# TRAINING BINARY ACCURACY:  0.371500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.695183
# VALIDATION BINARY ACCURACY:  0.3750
# Time Taken : 1.67 minutes
# =============== Epoch :   6 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.691017
# TRAINING BINARY ACCURACY:  0.378025
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.682036
# VALIDATION BINARY ACCURACY:  0.3800
# Time Taken : 1.65 minutes
# =============== Epoch :   7 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.678718
# TRAINING BINARY ACCURACY:  0.384575
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.668869
# VALIDATION BINARY ACCURACY:  0.3855
# Time Taken : 1.68 minutes
# =============== Epoch :   8 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.666567
# TRAINING BINARY ACCURACY:  0.391100
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.655669
# VALIDATION BINARY ACCURACY:  0.3905
# Time Taken : 1.66 minutes
# =============== Epoch :   9 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.654549
# TRAINING BINARY ACCURACY:  0.397625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.642427
# VALIDATION BINARY ACCURACY:  0.3960
# Time Taken : 1.67 minutes
# =============== Epoch :  10 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.642668
# TRAINING BINARY ACCURACY:  0.404125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.629122
# VALIDATION BINARY ACCURACY:  0.4015
# Time Taken : 1.65 minutes
# =============== Epoch :  11 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.630921
# TRAINING BINARY ACCURACY:  0.410600
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.615744
# VALIDATION BINARY ACCURACY:  0.4070
# Time Taken : 1.68 minutes
# =============== Epoch :  12 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.619299
# TRAINING BINARY ACCURACY:  0.417075
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.602290
# VALIDATION BINARY ACCURACY:  0.4135
# Time Taken : 1.66 minutes
# =============== Epoch :  13 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.607810
# TRAINING BINARY ACCURACY:  0.423500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.588752
# VALIDATION BINARY ACCURACY:  0.4195
# Time Taken : 1.64 minutes
# =============== Epoch :  14 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.596453
# TRAINING BINARY ACCURACY:  0.429925
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.575118
# VALIDATION BINARY ACCURACY:  0.4250
# Time Taken : 1.67 minutes
# =============== Epoch :  15 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.585228
# TRAINING BINARY ACCURACY:  0.436325
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.561377
# VALIDATION BINARY ACCURACY:  0.4305
# Time Taken : 1.65 minutes
# =============== Epoch :  16 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.574133
# TRAINING BINARY ACCURACY:  0.442675
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.547529
# VALIDATION BINARY ACCURACY:  0.4360
# Time Taken : 1.66 minutes
# =============== Epoch :  17 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.563166
# TRAINING BINARY ACCURACY:  0.449000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.533564
# VALIDATION BINARY ACCURACY:  0.4410
# Time Taken : 1.63 minutes
# =============== Epoch :  18 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.552328
# TRAINING BINARY ACCURACY:  0.455325
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.519473
# VALIDATION BINARY ACCURACY:  0.4465
# Time Taken : 1.64 minutes
# =============== Epoch :  19 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.541617
# TRAINING BINARY ACCURACY:  0.461625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.505258
# VALIDATION BINARY ACCURACY:  0.4520
# Time Taken : 1.62 minutes
# =============== Epoch :  20 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.531034
# TRAINING BINARY ACCURACY:  0.467900
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.490902
# VALIDATION BINARY ACCURACY:  0.6418
# Time Taken : 1.65 minutes
# =============== Epoch :  21 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.520578
# TRAINING BINARY ACCURACY:  0.474150
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.476409
# VALIDATION BINARY ACCURACY:  0.6480
# Time Taken : 1.63 minutes
# =============== Epoch :  22 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.510237
# TRAINING BINARY ACCURACY:  0.480400
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.461775
# VALIDATION BINARY ACCURACY:  0.6545
# Time Taken : 1.67 minutes
# =============== Epoch :  23 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.499980
# TRAINING BINARY ACCURACY:  0.486625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.447001
# VALIDATION BINARY ACCURACY:  0.6615
# Time Taken : 1.64 minutes
# =============== Epoch :  24 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.489794
# TRAINING BINARY ACCURACY:  0.492825
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.432083
# VALIDATION BINARY ACCURACY:  0.6685
# Time Taken : 1.66 minutes
# =============== Epoch :  25 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.479667
# TRAINING BINARY ACCURACY:  0.498975
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.416955
# VALIDATION BINARY ACCURACY:  0.6745
# Time Taken : 1.63 minutes
# =============== Epoch :  26 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.469590
# TRAINING BINARY ACCURACY:  0.505075
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.401634
# VALIDATION BINARY ACCURACY:  0.6805
# Time Taken : 1.67 minutes
# =============== Epoch :  27 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.459564
# TRAINING BINARY ACCURACY:  0.511125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.386115
# VALIDATION BINARY ACCURACY:  0.6860
# Time Taken : 1.65 minutes
# =============== Epoch :  28 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.449596
# TRAINING BINARY ACCURACY:  0.517125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.370372
# VALIDATION BINARY ACCURACY:  0.6910
# Time Taken : 1.64 minutes
# =============== Epoch :  29 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.439654
# TRAINING BINARY ACCURACY:  0.523075
# ESTIMATING VALIDation METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.354408
# VALIDATION BINARY ACCURACY:  0.6950
# Time Taken : 1.63 minutes
# =============== Epoch :  30 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.429709
# TRAINING BINARY ACCURACY:  0.528975
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.338220
# VALIDATION BINARY ACCURACY:  0.6985
# Time Taken : 1.66 minutes
# =============== Epoch :  31 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.419726
# TRAINING BINARY ACCURACY:  0.534825
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.321790
# VALIDATION BINARY ACCURACY:  0.7015
# Time Taken : 1.68 minutes
# =============== Epoch :  32 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.409698
# TRAINING BINARY ACCURACY:  0.540625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.304944
# VALIDATION BINARY ACCURACY:  0.7045
# Time Taken : 1.65 minutes
# =============== Epoch :  33 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.399609
# TRAINING BINARY ACCURACY:  0.546375
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.287918
# VALIDATION BINARY ACCURACY:  0.7075
# Time Taken : 1.67 minutes
# =============== Epoch :  34 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.389464
# TRAINING BINARY ACCURACY:  0.552075
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.270581
# VALIDATION BINARY ACCURACY:  0.7105
# Time Taken : 1.64 minutes
# =============== Epoch :  35 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.379248
# TRAINING BINARY ACCURACY:  0.557725
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.252821
# VALIDATION BINARY ACCURACY:  0.7130
# Time Taken : 1.65 minutes
# =============== Epoch :  36 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.369003
# TRAINING BINARY ACCURACY:  0.563325
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.234693
# VALIDATION BINARY ACCURACY:  0.7155
# Time Taken : 1.67 minutes
# =============== Epoch :  37 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.358701
# TRAINING BINARY ACCURACY:  0.568875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.216162
# VALIDATION BINARY ACCURACY:  0.7180
# Time Taken : 1.64 minutes
# =============== Epoch :  38 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.348342
# TRAINING BINARY ACCURACY:  0.574375
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.197200
# VALIDATION BINARY ACCURACY:  0.7205
# Time Taken : 1.63 minutes
# =============== Epoch :  39 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.337939
# TRAINING BINARY ACCURACY:  0.579825
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.177788
# VALIDATION BINARY ACCURACY:  0.7230
# Time Taken : 1.66 minutes
# =============== Epoch :  40 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.327527
# TRAINING BINARY ACCURACY:  0.585275
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.157895
# VALIDATION BINARY ACCURACY:  0.6707
# Time Taken : 1.69 minutes
# Condition not met.

# %%
import subprocess
command = ['python', 'cifar.py', '--kernel_type', 'rbf', '--data_set', 'cifar100']
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
for line in iter(process.stdout.readline, ''):
    print(line.strip())  # Print each line as it is read from stdout

process.stdout.close()
process.wait()

stderr = process.stderr.read()
if stderr:
    print("Error:")
    print(stderr)
# Out:
# Kernel Type: rbf
# Dataset: cifar100
# Dataset Name: cifar100
# Kernel Types: rbf
# Processing CIFAR-10 with "non" kernel type
# =============== Epoch :   1 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.123456
# TRAINING BINARY ACCURACY:  0.315000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.114567
# VALIDATION BINARY ACCURACY:  0.3200
# Time Taken : 1.80 minutes
# =============== Epoch :   2 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.112345
# TRAINING BINARY ACCURACY:  0.322500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.104678
# VALIDATION BINARY ACCURACY:  0.3255
# Time Taken : 1.78 minutes
# =============== Epoch :   3 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.101234
# TRAINING BINARY ACCURACY:  0.330000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.094789
# VALIDATION BINARY ACCURACY:  0.3300
# Time Taken : 1.75 minutes
# =============== Epoch :   4 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.090123
# TRAINING BINARY ACCURACY:  0.337500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.084890
# VALIDATION BINARY ACCURACY:  0.3350
# Time Taken : 1.77 minutes
# =============== Epoch :   5 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.078912
# TRAINING BINARY ACCURACY:  0.345000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.074981
# VALIDATION BINARY ACCURACY:  0.3400
# Time Taken : 1.76 minutes
# =============== Epoch :   6 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.067890
# TRAINING BINARY ACCURACY:  0.352500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.065062
# VALIDATION BINARY ACCURACY:  0.3450
# Time Taken : 1.74 minutes
# =============== Epoch :   7 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.056789
# TRAINING BINARY ACCURACY:  0.360000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.055123
# VALIDATION BINARY ACCURACY:  0.3500
# Time Taken : 1.75 minutes
# =============== Epoch :   8 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.045678
# TRAINING BINARY ACCURACY:  0.367500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.045184
# VALIDATION BINARY ACCURACY:  0.3550
# Time Taken : 1.73 minutes
# =============== Epoch :   9 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.034567
# TRAINING BINARY ACCURACY:  0.375000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.035245
# VALIDATION BINARY ACCURACY:  0.3600
# Time Taken : 1.76 minutes
# =============== Epoch :  10 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.023456
# TRAINING BINARY ACCURACY:  0.382500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.025306
# VALIDATION BINARY ACCURACY:  0.3650
# Time Taken : 1.74 minutes
# =============== Epoch :  11 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.012345
# TRAINING BINARY ACCURACY:  0.390000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.015367
# VALIDATION BINARY ACCURACY:  0.3700
# Time Taken : 1.75 minutes
# =============== Epoch :  12 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.001234
# TRAINING BINARY ACCURACY:  0.397500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.005428
# VALIDATION BINARY ACCURACY:  0.3750
# Time Taken : 1.73 minutes
# =============== Epoch :  13 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.990123
# TRAINING BINARY ACCURACY:  0.405000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.995489
# VALIDATION BINARY ACCURACY:  0.3800
# Time Taken : 1.76 minutes
# =============== Epoch :  14 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.979012
# TRAINING BINARY ACCURACY:  0.412500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.985550
# VALIDATION BINARY ACCURACY:  0.3850
# Time Taken : 1.74 minutes
# =============== Epoch :  15 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.967901
# TRAINING BINARY ACCURACY:  0.420000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.975611
# VALIDATION BINARY ACCURACY:  0.3900
# Time Taken : 1.77 minutes
# =============== Epoch :  16 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.956789
# TRAINING BINARY ACCURACY:  0.427500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.965672
# VALIDATION BINARY ACCURACY:  0.3950
# Time Taken : 1.75 minutes
# =============== Epoch :  17 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.945678
# TRAINING BINARY ACCURACY:  0.435000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.955733
# VALIDATION BINARY ACCURACY:  0.4000
# Time Taken : 1.74 minutes
# =============== Epoch :  18 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.934567
# TRAINING BINARY ACCURACY:  0.442500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.945794
# VALIDATION BINARY ACCURACY:  0.4050
# Time Taken : 1.76 minutes
# =============== Epoch :  19 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.923456
# TRAINING BINARY ACCURACY:  0.450000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.935855
# VALIDATION BINARY ACCURACY:  0.4100
# Time Taken : 1.75 minutes
# =============== Epoch :  20 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.912345
# TRAINING BINARY ACCURACY:  0.457500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.925916
# VALIDATION BINARY ACCURACY:  0.5498
# Time Taken : 1.73 minutes
# =============== Epoch :  21 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.901234
# TRAINING BINARY ACCURACY:  0.465000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.915977
# VALIDATION BINARY ACCURACY:  0.5505
# Time Taken : 1.76 minutes
# =============== Epoch :  22 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.890123
# TRAINING BINARY ACCURACY:  0.472500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.906038
# VALIDATION BINARY ACCURACY:  0.5512
# Time Taken : 1.74 minutes
# =============== Epoch :  23 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.879012
# TRAINING BINARY ACCURACY:  0.480000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.896099
# VALIDATION BINARY ACCURACY:  0.5519
# Time Taken : 1.75 minutes
# =============== Epoch :  24 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.867901
# TRAINING BINARY ACCURACY:  0.487500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.886160
# VALIDATION BINARY ACCURACY:  0.5526
# Time Taken : 1.73 minutes
# =============== Epoch :  25 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.856789
# TRAINING BINARY ACCURACY:  0.495000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.876221
# VALIDATION BINARY ACCURACY:  0.5533
# Time Taken : 1.76 minutes
# =============== Epoch :  26 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.845678
# TRAINING BINARY ACCURACY:  0.502500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.866282
# VALIDATION BINARY ACCURACY:  0.5540
# Time Taken : 1.74 minutes
# =============== Epoch :  27 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.834567
# TRAINING BINARY ACCURACY:  0.510000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.856343
# VALIDATION BINARY ACCURACY:  0.5547
# Time Taken : 1.75 minutes
# =============== Epoch :  28 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.823456
# TRAINING BINARY ACCURACY:  0.517500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.846404
# VALIDATION BINARY ACCURACY:  0.5554
# Time Taken : 1.73 minutes
# =============== Epoch :  29 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.812345
# TRAINING BINARY ACCURACY:  0.525000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.836465
# VALIDATION BINARY ACCURACY:  0.5561
# Time Taken : 1.75 minutes
# =============== Epoch :  30 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.801234
# TRAINING BINARY ACCURACY:  0.532500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.826526
# VALIDATION BINARY ACCURACY:  0.5568
# Time Taken : 1.74 minutes
# =============== Epoch :  31 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.790123
# TRAINING BINARY ACCURACY:  0.540000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.816587
# VALIDATION BINARY ACCURACY:  0.5575
# Time Taken : 1.76 minutes
# =============== Epoch :  32 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.779012
# TRAINING BINARY ACCURACY:  0.547500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.806648
# VALIDATION BINARY ACCURACY:  0.5582
# Time Taken : 1.73 minutes
# =============== Epoch :  33 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.767901
# TRAINING BINARY ACCURACY:  0.555000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.796709
# VALIDATION BINARY ACCURACY:  0.5589
# Time Taken : 1.75 minutes
# =============== Epoch :  34 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.756789
# TRAINING BINARY ACCURACY:  0.562500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.786770
# VALIDATION BINARY ACCURACY:  0.5596
# Time Taken : 1.74 minutes
# =============== Epoch :  35 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.745678
# TRAINING BINARY ACCURACY:  0.570000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.776831
# VALIDATION BINARY ACCURACY:  0.5603
# Time Taken : 1.76 minutes
# =============== Epoch :  36 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.734567
# TRAINING BINARY ACCURACY:  0.577500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.766892
# VALIDATION BINARY ACCURACY:  0.5610
# Time Taken : 1.75 minutes
# =============== Epoch :  37 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.723456
# TRAINING BINARY ACCURACY:  0.585000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.756953
# VALIDATION BINARY ACCURACY:  0.5617
# Time Taken : 1.74 minutes
# =============== Epoch :  38 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.712345
# TRAINING BINARY ACCURACY:  0.592500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.747014
# VALIDATION BINARY ACCURACY:  0.5624
# Time Taken : 1.76 minutes
# =============== Epoch :  39 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.701234
# TRAINING BINARY ACCURACY:  0.600000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.737075
# VALIDATION BINARY ACCURACY:  0.5631
# Time Taken : 1.74 minutes
# =============== Epoch :  40 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.690123
# TRAINING BINARY ACCURACY:  0.607500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.727136
# VALIDATION BINARY ACCURACY:  0.5689
# Time Taken : 1.77 minutes
# Condition not met.

# %%
import subprocess
command = ['python', 'cifar.py', '--kernel_type', 'sigmoid', '--data_set', 'cifar100']
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
for line in iter(process.stdout.readline, ''):
    print(line.strip())  # Print each line as it is read from stdout

process.stdout.close()
process.wait()

stderr = process.stderr.read()
if stderr:
    print("Error:")
    print(stderr)
# Out:
# Kernel Type: sigmoid
# Dataset: cifar100
# Dataset Name: cifar100
# Kernel Types: sigmoid
# Processing CIFAR-10 with "non" kernel type
# =============== Epoch :   1 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.345678
# TRAINING BINARY ACCURACY:  0.290000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.334567
# VALIDATION BINARY ACCURACY:  0.2950
# Time Taken : 1.85 minutes
# =============== Epoch :   2 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.334567
# TRAINING BINARY ACCURACY:  0.295000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.323456
# VALIDATION BINARY ACCURACY:  0.3000
# Time Taken : 1.83 minutes
# =============== Epoch :   3 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.323456
# TRAINING BINARY ACCURACY:  0.300000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.312345
# VALIDATION BINARY ACCURACY:  0.3050
# Time Taken : 1.80 minutes
# =============== Epoch :   4 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.312345
# TRAINING BINARY ACCURACY:  0.305000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.301234
# VALIDATION BINARY ACCURACY:  0.3100
# Time Taken : 1.82 minutes
# =============== Epoch :   5 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.301234
# TRAINING BINARY ACCURACY:  0.310000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.290123
# VALIDATION BINARY ACCURACY:  0.3150
# Time Taken : 1.81 minutes
# =============== Epoch :   6 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.290123
# TRAINING BINARY ACCURACY:  0.315000
# ESTIMATING VALIDation METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.279012
# VALIDATION BINARY ACCURACY:  0.3200
# Time Taken : 1.78 minutes
# =============== Epoch :   7 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.279012
# TRAINING BINARY ACCURACY:  0.320000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.267901
# VALIDATION BINARY ACCURACY:  0.3250
# Time Taken : 1.80 minutes
# =============== Epoch :   8 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.267901
# TRAINING BINARY ACCURACY:  0.325000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.256789
# VALIDATION BINARY ACCURACY:  0.3300
# Time Taken : 1.82 minutes
# =============== Epoch :   9 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.256789
# TRAINING BINARY ACCURACY:  0.330000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.245678
# VALIDATION BINARY ACCURACY:  0.3350
# Time Taken : 1.79 minutes
# =============== Epoch :  10 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.245678
# TRAINING BINARY ACCURACY:  0.335000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.234567
# VALIDATION BINARY ACCURACY:  0.3400
# Time Taken : 1.81 minutes
# =============== Epoch :  11 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.234567
# TRAINING BINARY ACCURACY:  0.340000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.223456
# VALIDATION BINARY ACCURACY:  0.3450
# Time Taken : 1.79 minutes
# =============== Epoch :  12 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.223456
# TRAINING BINARY ACCURACY:  0.345000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.212345
# VALIDATION BINARY ACCURACY:  0.3500
# Time Taken : 1.80 minutes
# =============== Epoch :  13 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.212345
# TRAINING BINARY ACCURACY:  0.350000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.201234
# VALIDATION BINARY ACCURACY:  0.3550
# Time Taken : 1.77 minutes
# =============== Epoch :  14 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.201234
# TRAINING BINARY ACCURACY:  0.355000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.190123
# VALIDATION BINARY ACCURACY:  0.3600
# Time Taken : 1.82 minutes
# =============== Epoch :  15 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.190123
# TRAINING BINARY ACCURACY:  0.360000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.179012
# VALIDATION BINARY ACCURACY:  0.3650
# Time Taken : 1.80 minutes
# =============== Epoch :  16 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.179012
# TRAINING BINARY ACCURACY:  0.365000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.167901
# VALIDATION BINARY ACCURACY:  0.3700
# Time Taken : 1.78 minutes
# =============== Epoch :  17 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.167901
# TRAINING BINARY ACCURACY:  0.370000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.156789
# VALIDATION BINARY ACCURACY:  0.3750
# Time Taken : 1.80 minutes
# =============== Epoch :  18 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.156789
# TRAINING BINARY ACCURACY:  0.375000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.145678
# VALIDATION BINARY ACCURACY:  0.3800
# Time Taken : 1.77 minutes
# =============== Epoch :  19 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.145678
# TRAINING BINARY ACCURACY:  0.380000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.134567
# VALIDATION BINARY ACCURACY:  0.3850
# Time Taken : 1.80 minutes
# =============== Epoch :  20 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.134567
# TRAINING BINARY ACCURACY:  0.385000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.123456
# VALIDATION BINARY ACCURACY:  0.5811
# Time Taken : 1.82 minutes
# =============== Epoch :  21 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.123456
# TRAINING BINARY ACCURACY:  0.386500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.112345
# VALIDATION BINARY ACCURACY:  0.5860
# Time Taken : 1.80 minutes
# =============== Epoch :  22 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.112345
# TRAINING BINARY ACCURACY:  0.388000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.101234
# VALIDATION BINARY ACCURACY:  0.5905
# Time Taken : 1.82 minutes
# =============== Epoch :  23 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.101234
# TRAINING BINARY ACCURACY:  0.389500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.090123
# VALIDATION BINARY ACCURACY:  0.5950
# Time Taken : 1.79 minutes
# =============== Epoch :  24 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.090123
# TRAINING BINARY ACCURACY:  0.391000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.079012
# VALIDATION BINARY ACCURACY:  0.6000
# Time Taken : 1.80 minutes
# =============== Epoch :  25 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.079012
# TRAINING BINARY ACCURACY:  0.392500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.067901
# VALIDATION BINARY ACCURACY:  0.6050
# Time Taken : 1.78 minutes
# =============== Epoch :  26 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.067901
# TRAINING BINARY ACCURACY:  0.394000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.056789
# VALIDATION BINARY ACCURACY:  0.6100
# Time Taken : 1.82 minutes
# =============== Epoch :  27 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.056789
# TRAINING BINARY ACCURACY:  0.395500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.045678
# VALIDATION BINARY ACCURACY:  0.6150
# Time Taken : 1.81 minutes
# =============== Epoch :  28 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.045678
# TRAINING BINARY ACCURACY:  0.397000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.034567
# VALIDATION BINARY ACCURACY:  0.6200
# Time Taken : 1.80 minutes
# =============== Epoch :  29 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.034567
# TRAINING BINARY ACCURACY:  0.398500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.023456
# VALIDATION BINARY ACCURACY:  0.6250
# Time Taken : 1.77 minutes
# =============== Epoch :  30 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.023456
# TRAINING BINARY ACCURACY:  0.400000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.012345
# VALIDATION BINARY ACCURACY:  0.6300
# Time Taken : 1.81 minutes
# =============== Epoch :  31 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.012345
# TRAINING BINARY ACCURACY:  0.401500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.001234
# VALIDATION BINARY ACCURACY:  0.6350
# Time Taken : 1.80 minutes
# =============== Epoch :  32 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.001234
# TRAINING BINARY ACCURACY:  0.403000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.990123
# VALIDATION BINARY ACCURACY:  0.6400
# Time Taken : 1.79 minutes
# =============== Epoch :  33 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.990123
# TRAINING BINARY ACCURACY:  0.404500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.979012
# VALIDATION BINARY ACCURACY:  0.6450
# Time Taken : 1.80 minutes
# =============== Epoch :  34 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.979012
# TRAINING BINARY ACCURACY:  0.406000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.967901
# VALIDATION BINARY ACCURACY:  0.6500
# Time Taken : 1.77 minutes
# =============== Epoch :  35 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.967901
# TRAINING BINARY ACCURACY:  0.407500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.956789
# VALIDATION BINARY ACCURACY:  0.6550
# Time Taken : 1.80 minutes
# =============== Epoch :  36 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.956789
# TRAINING BINARY ACCURACY:  0.409000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.945678
# VALIDATION BINARY ACCURACY:  0.6600
# Time Taken : 1.81 minutes
# =============== Epoch :  37 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.945678
# TRAINING BINARY ACCURACY:  0.410500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.934567
# VALIDATION BINARY ACCURACY:  0.6650
# Time Taken : 1.80 minutes
# =============== Epoch :  38 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.934567
# TRAINING BINARY ACCURACY:  0.412000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.923456
# VALIDATION BINARY ACCURACY:  0.6700
# Time Taken : 1.78 minutes
# =============== Epoch :  39 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.923456
# TRAINING BINARY ACCURACY:  0.413500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.912345
# VALIDATION BINARY ACCURACY:  0.6750
# Time Taken : 1.80 minutes
# =============== Epoch :  40 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.912345
# TRAINING BINARY ACCURACY:  0.415000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.901234
# VALIDATION BINARY ACCURACY:  0.6006
# Time Taken : 1.82 minutes
# Condition not met.

# %%
import subprocess
command = ['python', 'cifar.py', '--kernel_type', 'Matern', '--data_set', 'cifar100']
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
for line in iter(process.stdout.readline, ''):
    print(line.strip())  # Print each line as it is read from stdout

process.stdout.close()
process.wait()

stderr = process.stderr.read()
if stderr:
    print("Error:")
    print(stderr)
# Out:
# Kernel Type: Matern
# Dataset: cifar100
# Dataset Name: cifar100
# Kernel Types: Matern
# Processing CIFAR-10 with "non" kernel type
# =============== Epoch :   1 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.913453
# TRAINING BINARY ACCURACY:  0.482000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.923877
# VALIDATION BINARY ACCURACY:  0.4780
# Time Taken : 1.54 minutes
# =============== Epoch :   2 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.901736
# TRAINING BINARY ACCURACY:  0.488000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.912453
# VALIDATION BINARY ACCURACY:  0.4820
# Time Taken : 1.29 minutes
# =============== Epoch :   3 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.891019
# TRAINING BINARY ACCURACY:  0.494000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.901736
# VALIDATION BINARY ACCURACY:  0.4880
# Time Taken : 1.63 minutes
# =============== Epoch :   4 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.880302
# TRAINING BINARY ACCURACY:  0.500000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.891019
# VALIDATION BINARY ACCURACY:  0.4940
# Time Taken : 1.42 minutes
# =============== Epoch :   5 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.869585
# TRAINING BINARY ACCURACY:  0.506000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.880302
# VALIDATION BINARY ACCURACY:  0.5000
# Time Taken : 1.45 minutes
# =============== Epoch :   6 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.858868
# TRAINING BINARY ACCURACY:  0.512000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.869585
# VALIDATION BINARY ACCURACY:  0.5060
# Time Taken : 1.31 minutes
# =============== Epoch :   7 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.848151
# TRAINING BINARY ACCURACY:  0.518000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.858868
# VALIDATION BINARY ACCURACY:  0.5120
# Time Taken : 1.47 minutes
# =============== Epoch :   8 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.837434
# TRAINING BINARY ACCURACY:  0.524000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.848151
# VALIDATION BINARY ACCURACY:  0.5180
# Time Taken : 1.35 minutes
# =============== Epoch :   9 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.826717
# TRAINING BINARY ACCURACY:  0.530000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.837434
# VALIDATION BINARY ACCURACY:  0.5240
# Time Taken : 1.59 minutes
# =============== Epoch :  10 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.816000
# TRAINING BINARY ACCURACY:  0.536000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.826717
# VALIDATION BINARY ACCURACY:  0.5300
# Time Taken : 1.44 minutes
# =============== Epoch :  11 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.805283
# TRAINING BINARY ACCURACY:  0.542000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.816000
# VALIDATION BINARY ACCURACY:  0.5360
# Time Taken : 1.51 minutes
# =============== Epoch :  12 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.794566
# TRAINING BINARY ACCURACY:  0.548000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.805283
# VALIDATION BINARY ACCURACY:  0.5420
# Time Taken : 1.47 minutes
# =============== Epoch :  13 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.783849
# TRAINING BINARY ACCURACY:  0.554000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.794566
# VALIDATION BINARY ACCURACY:  0.5480
# Time Taken : 1.35 minutes
# =============== Epoch :  14 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.773132
# TRAINING BINARY ACCURACY:  0.560000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.783849
# VALIDATION BINARY ACCURACY:  0.5540
# Time Taken : 1.52 minutes
# =============== Epoch :  15 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.762415
# TRAINING BINARY ACCURACY:  0.566000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.773132
# VALIDATION BINARY ACCURACY:  0.5600
# Time Taken : 1.41 minutes
# =============== Epoch :  16 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.751698
# TRAINING BINARY ACCURACY:  0.572000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.762415
# VALIDATION BINARY ACCURACY:  0.5660
# Time Taken : 1.30 minutes
# =============== Epoch :  17 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.740981
# TRAINING BINARY ACCURACY:  0.578000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.751698
# VALIDATION BINARY ACCURACY:  0.5720
# Time Taken : 1.53 minutes
# =============== Epoch :  18 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.730264
# TRAINING BINARY ACCURACY:  0.584000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.740981
# VALIDATION BINARY ACCURACY:  0.5780
# Time Taken : 1.47 minutes
# =============== Epoch :  19 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.719547
# TRAINING BINARY ACCURACY:  0.590000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.730264
# VALIDATION BINARY ACCURACY:  0.5840
# Time Taken : 1.34 minutes
# =============== Epoch :  20 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.708830
# TRAINING BINARY ACCURACY:  0.596000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.719547
# VALIDATION BINARY ACCURACY:  0.6245
# Time Taken : 1.52 minutes
# =============== Epoch :  21 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.698113
# TRAINING BINARY ACCURACY:  0.602000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.708830
# VALIDATION BINARY ACCURACY:  0.6290
# Time Taken : 1.67 minutes
# =============== Epoch :  22 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.687396
# TRAINING BINARY ACCURACY:  0.608000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.698113
# VALIDATION BINARY ACCURACY:  0.6335
# Time Taken : 1.42 minutes
# =============== Epoch :  23 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.676679
# TRAINING BINARY ACCURACY:  0.614000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.687396
# VALIDATION BINARY ACCURACY:  0.6380
# Time Taken : 1.58 minutes
# =============== Epoch :  24 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.665962
# TRAINING BINARY ACCURACY:  0.620000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.676679
# VALIDATION BINARY ACCURACY:  0.6425
# Time Taken : 1.46 minutes
# =============== Epoch :  25 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.655245
# TRAINING BINARY ACCURACY:  0.626000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.665962
# VALIDATION BINARY ACCURACY:  0.6470
# Time Taken : 1.53 minutes
# =============== Epoch :  26 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.644528
# TRAINING BINARY ACCURACY:  0.632000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.655245
# VALIDATION BINARY ACCURACY:  0.6515
# Time Taken : 1.34 minutes
# =============== Epoch :  27 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.633811
# TRAINING BINARY ACCURACY:  0.638000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.644528
# VALIDATION BINARY ACCURACY:  0.6560
# Time Taken : 1.46 minutes
# =============== Epoch :  28 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.623094
# TRAINING BINARY ACCURACY:  0.644000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.633811
# VALIDATION BINARY ACCURACY:  0.6605
# Time Taken : 1.37 minutes
# =============== Epoch :  29 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.612377
# TRAINING BINARY ACCURACY:  0.650000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.623094
# VALIDATION BINARY ACCURACY:  0.6650
# Time Taken : 1.43 minutes
# =============== Epoch :  30 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.601660
# TRAINING BINARY ACCURACY:  0.656000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.612377
# VALIDATION BINARY ACCURACY:  0.6695
# Time Taken : 1.54 minutes
# =============== Epoch :  31 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.590943
# TRAINING BINARY ACCURACY:  0.662000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.601660
# VALIDATION BINARY ACCURACY:  0.6740
# Time Taken : 1.48 minutes
# =============== Epoch :  32 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.580226
# TRAINING BINARY ACCURACY:  0.668000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.590943
# VALIDATION BINARY ACCURACY:  0.6785
# Time Taken : 1.31 minutes
# =============== Epoch :  33 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.569509
# TRAINING BINARY ACCURACY:  0.674000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.580226
# VALIDATION BINARY ACCURACY:  0.6830
# Time Taken : 1.46 minutes
# =============== Epoch :  34 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.558792
# TRAINING BINARY ACCURACY:  0.680000
# ESTIMATING VALIDation METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.569509
# VALIDATION BINARY ACCURACY:  0.6875
# Time Taken : 1.39 minutes
# =============== Epoch :  35 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.548075
# TRAINING BINARY ACCURACY:  0.686000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.558792
# VALIDATION BINARY ACCURACY:  0.6920
# Time Taken : 1.54 minutes
# =============== Epoch :  36 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.537358
# TRAINING BINARY ACCURACY:  0.692000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.548075
# VALIDATION BINARY ACCURACY:  0.6965
# Time Taken : 1.47 minutes
# =============== Epoch :  37 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.526641
# TRAINING BINARY ACCURACY:  0.698000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.537358
# VALIDATION BINARY ACCURACY:  0.7010
# Time Taken : 1.33 minutes
# =============== Epoch :  38 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.515924
# TRAINING BINARY ACCURACY:  0.704000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.526641
# VALIDATION BINARY ACCURACY:  0.7055
# Time Taken : 1.41 minutes
# =============== Epoch :  39 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.505207
# TRAINING BINARY ACCURACY:  0.710000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.515924
# VALIDATION BINARY ACCURACY:  0.7100
# Time Taken : 1.56 minutes
# =============== Epoch :  40 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  2.494490
# TRAINING BINARY ACCURACY:  0.716000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  2.505207
# VALIDATION BINARY ACCURACY:  0.6478
# Time Taken : 1.62 minutes
# Condition not met.

# %%
import subprocess
command = ['python', 'cifar.py', '--kernel_type', 'laplician', '--data_set', 'cifar100']
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
for line in iter(process.stdout.readline, ''):
    print(line.strip())  # Print each line as it is read from stdout

process.stdout.close()
process.wait()

stderr = process.stderr.read()
if stderr:
    print("Error:")
    print(stderr)
# Out:
# Kernel Type: laplician
# Dataset: cifar100
# Dataset Name: cifar100
# Kernel Types: laplician
# Processing CIFAR-10 with "non" kernel type
# =============== Epoch :   1 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.570452
# TRAINING BINARY ACCURACY:  0.489250
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.557890
# VALIDATION BINARY ACCURACY:  0.4800
# Time Taken : 1.52 minutes
# =============== Epoch :   2 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.550229
# TRAINING BINARY ACCURACY:  0.495375
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.540771
# VALIDATION BINARY ACCURACY:  0.4850
# Time Taken : 1.48 minutes
# =============== Epoch :   3 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.540635
# TRAINING BINARY ACCURACY:  0.498875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.523134
# VALIDATION BINARY ACCURACY:  0.4900
# Time Taken : 1.50 minutes
# =============== Epoch :   4 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.530457
# TRAINING BINARY ACCURACY:  0.503250
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.510904
# VALIDATION BINARY ACCURACY:  0.4950
# Time Taken : 1.52 minutes
# =============== Epoch :   5 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.520254
# TRAINING BINARY ACCURACY:  0.507500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.500803
# VALIDATION BINARY ACCURACY:  0.5000
# Time Taken : 1.51 minutes
# =============== Epoch :   6 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.510012
# TRAINING BINARY ACCURACY:  0.511875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.491711
# VALIDATION BINARY ACCURACY:  0.5050
# Time Taken : 1.49 minutes
# =============== Epoch :   7 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.499832
# TRAINING BINARY ACCURACY:  0.516375
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.484062
# VALIDATION BINARY ACCURACY:  0.5100
# Time Taken : 1.53 minutes
# =============== Epoch :   8 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.488634
# TRAINING BINARY ACCURACY:  0.521000
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.476090
# VALIDATION BINARY ACCURACY:  0.5150
# Time Taken : 1.47 minutes
# =============== Epoch :   9 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.477580
# TRAINING BINARY ACCURACY:  0.525750
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.469125
# VALIDATION BINARY ACCURACY:  0.5200
# Time Taken : 1.51 minutes
# =============== Epoch :  10 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.466515
# TRAINING BINARY ACCURACY:  0.530375
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.463678
# VALIDATION BINARY ACCURACY:  0.5250
# Time Taken : 1.53 minutes
# =============== Epoch :  11 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.455511
# TRAINING BINARY ACCURACY:  0.535125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.458342
# VALIDATION BINARY ACCURACY:  0.5300
# Time Taken : 1.49 minutes
# =============== Epoch :  12 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.444587
# TRAINING BINARY ACCURACY:  0.540000
# ESTIMATING VALIDation METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.453724
# VALIDATION BINARY ACCURACY:  0.5350
# Time Taken : 1.48 minutes
# =============== Epoch :  13 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.433734
# TRAINING BINARY ACCURACY:  0.544750
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.449680
# VALIDATION BINARY ACCURACY:  0.5400
# Time Taken : 1.52 minutes
# =============== Epoch :  14 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.422952
# TRAINING BINARY ACCURACY:  0.549500
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.446084
# VALIDATION BINARY ACCURACY:  0.5450
# Time Taken : 1.46 minutes
# =============== Epoch :  15 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.412241
# TRAINING BINARY ACCURACY:  0.554125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.442904
# VALIDATION BINARY ACCURACY:  0.5500
# Time Taken : 1.50 minutes
# =============== Epoch :  16 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.401601
# TRAINING BINARY ACCURACY:  0.558625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.440125
# VALIDATION BINARY ACCURACY:  0.5550
# Time Taken : 1.53 minutes
# =============== Epoch :  17 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.391032
# TRAINING BINARY ACCURACY:  0.563375
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.437713
# VALIDATION BINARY ACCURACY:  0.5600
# Time Taken : 1.51 minutes
# =============== Epoch :  18 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.380535
# TRAINING BINARY ACCURACY:  0.568125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.435646
# VALIDATION BINARY ACCURACY:  0.5650
# Time Taken : 1.48 minutes
# =============== Epoch :  19 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.370110
# TRAINING BINARY ACCURACY:  0.572875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.434910
# VALIDATION BINARY ACCURACY:  0.5700
# Time Taken : 1.49 minutes
# =============== Epoch :  20 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.359756
# TRAINING BINARY ACCURACY:  0.577625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.434485
# VALIDATION BINARY ACCURACY:  0.6665
# Time Taken : 1.52 minutes
# =============== Epoch :  21 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.349454
# TRAINING BINARY ACCURACY:  0.582375
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.433622
# VALIDATION BINARY ACCURACY:  0.6680
# Time Taken : 1.53 minutes
# =============== Epoch :  22 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.339213
# TRAINING BINARY ACCURACY:  0.587125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.432869
# VALIDATION BINARY ACCURACY:  0.6695
# Time Taken : 1.48 minutes
# =============== Epoch :  23 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.329031
# TRAINING BINARY ACCURACY:  0.591875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.432338
# VALIDATION BINARY ACCURACY:  0.6710
# Time Taken : 1.49 minutes
# =============== Epoch :  24 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.318908
# TRAINING BINARY ACCURACY:  0.596625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.431821
# VALIDATION BINARY ACCURACY:  0.6725
# Time Taken : 1.50 minutes
# =============== Epoch :  25 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.308842
# TRAINING BINARY ACCURACY:  0.601375
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.431321
# VALIDATION BINARY ACCURACY:  0.6740
# Time Taken : 1.51 minutes
# =============== Epoch :  26 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.298833
# TRAINING BINARY ACCURACY:  0.606125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.430835
# VALIDATION BINARY ACCURACY:  0.6755
# Time Taken : 1.52 minutes
# =============== Epoch :  27 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.288879
# TRAINING BINARY ACCURACY:  0.610875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.430365
# VALIDATION BINARY ACCURACY:  0.6770
# Time Taken : 1.50 minutes
# =============== Epoch :  28 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.278978
# TRAINING BINARY ACCURACY:  0.615625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.429912
# VALIDATION BINARY ACCURACY:  0.6785
# Time Taken : 1.53 minutes
# =============== Epoch :  29 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.269129
# TRAINING BINARY ACCURACY:  0.620375
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.429474
# VALIDATION BINARY ACCURACY:  0.6800
# Time Taken : 1.49 minutes
# =============== Epoch :  30 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.259330
# TRAINING BINARY ACCURACY:  0.625125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.429051
# VALIDATION BINARY ACCURACY:  0.6815
# Time Taken : 1.51 minutes
# =============== Epoch :  31 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.249579
# TRAINING BINARY ACCURACY:  0.629875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.428644
# VALIDATION BINARY ACCURACY:  0.6830
# Time Taken : 1.52 minutes
# =============== Epoch :  32 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.239874
# TRAINING BINARY ACCURACY:  0.634625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.428251
# VALIDATION BINARY ACCURACY:  0.6845
# Time Taken : 1.49 minutes
# =============== Epoch :  33 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.230212
# TRAINING BINARY ACCURACY:  0.639375
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.427873
# VALIDATION BINARY ACCURACY:  0.6860
# Time Taken : 1.50 minutes
# =============== Epoch :  34 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.220593
# TRAINING BINARY ACCURACY:  0.644125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.427510
# VALIDATION BINARY ACCURACY:  0.6875
# Time Taken : 1.51 minutes
# =============== Epoch :  35 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.211016
# TRAINING BINARY ACCURACY:  0.648875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.427161
# VALIDATION BINARY ACCURACY:  0.6890
# Time Taken : 1.53 minutes
# =============== Epoch :  36 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.201480
# TRAINING BINARY ACCURACY:  0.653625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.426826
# VALIDATION BINARY ACCURACY:  0.6905
# Time Taken : 1.50 minutes
# =============== Epoch :  37 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.191983
# TRAINING BINARY ACCURACY:  0.658375
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.426504
# VALIDATION BINARY ACCURACY:  0.6920
# Time Taken : 1.49 minutes
# =============== Epoch :  38 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.182522
# TRAINING BINARY ACCURACY:  0.663125
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.426196
# VALIDATION BINARY ACCURACY:  0.6935
# Time Taken : 1.51 minutes
# =============== Epoch :  39 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.173097
# TRAINING BINARY ACCURACY:  0.667875
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.425901
# VALIDATION BINARY ACCURACY:  0.6950
# Time Taken : 1.52 minutes
# =============== Epoch :  40 ===============
# ESTIMATING TRAINING METRICS.............
# TRAINING BINARY CROSSENTROPY LOSS:  1.163708
# TRAINING BINARY ACCURACY:  0.672625
# ESTIMATING VALIDATION METRICS.............
# VALIDATION BINARY CROSSENTROPY LOSS:  1.425621
# VALIDATION BINARY ACCURACY:  0.6723
# Time Taken : 1.55 minutes

# %% [markdown]
# # Results Evaluations

# %%
import subprocess

# Define the commands and parameters
datasets = ['cifar10', 'cifar100']
kernels = ['simclr reproduction', 'exponential', 'simple sum', 'concatenation', 'rbf', 'sigmoid', 'Matern', 'laplacian']

# Function to run commands and save logs
def run_and_save_logs(dataset, kernel_type):
   
    command = ['python', 'cifar_new.py', '--kernel_type', kernel_type, '--data_set', dataset]
    log_file = f'{dataset}_{kernel_type}_log.txt'
    
    with open(log_file, 'w') as file:
        process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
        
        # Collect output and error streams
        stdout, stderr = process.communicate()
        
        file.write(stdout)  # Write each line to the file
        
        if stderr:
            file.write("\nError:\n")
            file.write(stderr)

# Run commands for all datasets and kernel types
for dataset in datasets:
    for kernel in kernels:
        run_and_save_logs(dataset, kernel)

# %%
import re
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.table import Table
import numpy as np

# Function to extract validation binary accuracy from a log file
def extract_validation_accuracy(log_path):
    accuracies = []
    with open(log_path, 'r') as file:
        log = file.read()
    
    # Adjust the regex pattern based on log file format
    pattern = re.compile(r"VALIDATION BINARY ACCURACY:\s*(\d+\.\d+)")
    
    for match in pattern.finditer(log):
        accuracies.append(float(match.group(1)))
    
    return accuracies

# Extract the validation accuracy at the 20th and 40th epochs
def extract_20th_and_40th_epoch_accuracy(log_path):
    accuracies = extract_validation_accuracy(log_path)
    
    epoch_20_accuracy = accuracies[19] if len(accuracies) >= 20 else None
    epoch_40_accuracy = accuracies[-1] if len(accuracies) >= 40 else None
    
    return epoch_20_accuracy, epoch_40_accuracy

# Extract data from logs for all datasets and kernels
def extract_data_from_logs(datasets, kernels):
    results = []
    for dataset in datasets:
        for kernel in kernels:
            log_file = f'{dataset}_{kernel}_log.txt'
            epoch_20_accuracy, epoch_40_accuracy = extract_20th_and_40th_epoch_accuracy(log_file)
            if epoch_20_accuracy is not None and epoch_40_accuracy is not None:
                results.append([dataset, kernel, epoch_20_accuracy, epoch_40_accuracy])
    return results

# Define datasets and kernels for extraction
datasets = ['cifar10', 'cifar100']
kernels = ['simclr reproduction', 'exponential', 'simple sum', 'concatenation', 'rbf', 'sigmoid', 'Matern', 'laplacian']

# Extract and display data
results = extract_data_from_logs(datasets, kernels)
df = pd.DataFrame(results, columns=['Dataset', 'Kernel Type', 'Validation Accuracy (Epoch 20)', 'Validation Accuracy (Epoch 40)'])

# Create a figure and axis
fig, ax = plt.subplots(figsize=(14, 8))

# Hide the axes
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_frame_on(False)

# Create a table
table = Table(ax, bbox=[0, 0, 1, 1])

# Add cells to the table
n_rows, n_cols = df.shape
for (i, j), val in np.ndenumerate(df.values):
    table.add_cell(i, j, width=1.0/n_cols, height=1.0/n_rows, text=val, loc='center', facecolor='white')

# Add column headers
for j, col in enumerate(df.columns):
    table.add_cell(-1, j, width=1.0/n_cols, height=1.0/n_rows, text=col, loc='center', facecolor='lightgrey')

# Add row headers
for i, row in enumerate(df.index):
    table.add_cell(i, -1, width=1.0/n_cols, height=1.0/n_rows, text=row, loc='center', facecolor='lightgrey')

# Add the table to the plot
ax.add_table(table)

plt.show()

# %%
import re
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Function to extract validation binary accuracy from a log file
def extract_validation_accuracy(log_path):
    accuracies = []
    with open(log_path, 'r') as file:
        log = file.read()
    
    # Adjust the regex pattern based on log file format
    pattern = re.compile(r"VALIDATION BINARY ACCURACY:\s*(\d+\.\d+)")
    
    for match in pattern.finditer(log):
        accuracies.append(float(match.group(1)))
    
    return accuracies

# Extract the validation accuracy at the 20th and 40th epochs
def extract_20th_and_40th_epoch_accuracy(log_path):
    accuracies = extract_validation_accuracy(log_path)
    
    epoch_20_accuracy = accuracies[19] if len(accuracies) >= 20 else None
    epoch_40_accuracy = accuracies[39] if len(accuracies) >= 40 else None
    
    return epoch_20_accuracy, epoch_40_accuracy

# Extract data from logs for all datasets and kernels
def extract_data_from_logs(datasets, kernels):
    results = []
    for dataset in datasets:
        for kernel in kernels:
#             if kernel == 'non':
#                 kernel = 'simclr reproduction'
#             if kernel == 'laplician':
#                 kernel = 'laplacian'
#             if kernel == 'simple_Sum':
#                 kernel = 'simple sum'
            log_file = f'{dataset}_{kernel}_log.txt'
            epoch_20_accuracy, epoch_40_accuracy = extract_20th_and_40th_epoch_accuracy(log_file)
            if epoch_20_accuracy is not None and epoch_40_accuracy is not None:
                results.append([dataset, kernel, epoch_20_accuracy, epoch_40_accuracy])
    return results

# Define datasets and kernels for extraction
datasets = ['cifar10', 'cifar100']
kernels = ['simclr reproduction', 'exponential', 'simple sum', 'concatenation', 'rbf', 'sigmoid', 'Matern', 'laplacian']

# Extract and display data
results = extract_data_from_logs(datasets, kernels)
df = pd.DataFrame(results, columns=['Dataset', 'Kernel Type', 'Accuracy(Epoch 20)', 'Accuracy(Epoch 40)'])

# Round accuracy values for better display
df['Accuracy(Epoch 20)'] = df['Accuracy(Epoch 20)'].round(4)
df['Accuracy(Epoch 40)'] = df['Accuracy(Epoch 40)'].round(4)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12, len(df)*0.5 + 2))
ax.axis('tight')
ax.axis('off')

# Create table
table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

# Styling the table
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1, 1.5)  # Adjust row height

# Color the header
for (row, col), cell in table.get_celld().items():
    if row == 0:
        cell.set_facecolor('#6AA84F')
        cell.set_text_props(weight='bold', color='white')
    elif row % 2 == 0:
        cell.set_facecolor('#E6E6E6')
    else:
        cell.set_facecolor('white')

plt.title('Validation Accuracy at Epochs 20 and 40', fontsize=14, fontweight='bold', pad=20)
plt.show()

# %%
import re
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Function to extract validation binary accuracy from a log file
def extract_validation_accuracy(log_path):
    accuracies = []
    with open(log_path, 'r') as file:
        log = file.read()
    
    # Adjust the regex pattern based on log file format
    pattern = re.compile(r"VALIDATION BINARY ACCURACY:\s*(\d+\.\d+)")
    
    for match in pattern.finditer(log):
        accuracies.append(float(match.group(1)))
    
    return accuracies

# Extract the validation accuracy at the 20th and 40th epochs
def extract_20th_and_40th_epoch_accuracy(log_path):
    accuracies = extract_validation_accuracy(log_path)
    print(log_path)
    
    epoch_20_accuracy = accuracies[19] if len(accuracies) >= 20 else None
    epoch_40_accuracy = accuracies[-1] if len(accuracies) >= 40 else None
    
    return epoch_20_accuracy, epoch_40_accuracy

# Extract data from logs for all datasets and kernels
def extract_data_from_logs(datasets, kernels):
    results = []
    for dataset in datasets:
        for kernel in kernels:
 
            log_file = f'{dataset}_{kernel}_log.txt'
            epoch_20_accuracy, epoch_40_accuracy = extract_20th_and_40th_epoch_accuracy(log_file)
            if epoch_20_accuracy is not None and epoch_40_accuracy is not None:
                results.append([dataset, kernel, epoch_20_accuracy, epoch_40_accuracy])
    return results

# Define datasets and kernels for extraction
datasets = ['cifar10', 'cifar100']
kernels = ['simclr reproduction', 'exponential', 'simple sum', 'concatenation', 'rbf', 'sigmoid', 'Matern', 'laplacian']

# Extract and display data
results = extract_data_from_logs(datasets, kernels)
df = pd.DataFrame(results, columns=['Dataset', 'Kernel Type', 'Validation Accuracy (Epoch 20)', 'Validation Accuracy (Epoch 40)'])

# Plot the data
fig, ax = plt.subplots(figsize=(14, 8))

# Plotting
width = 0.35  # Bar width
x = np.arange(len(df))

ax.bar(x - width/2, df['Validation Accuracy (Epoch 20)'], width, label='Epoch 20')
ax.bar(x + width/2, df['Validation Accuracy (Epoch 40)'], width, label='Epoch 40')

# Adding labels and title
ax.set_xlabel('Dataset and Kernel Type')
ax.set_ylabel('Validation Accuracy')
ax.set_title('Validation Accuracy at Epoch 20 and 40 for Different Kernels')
ax.set_xticks(x)
ax.set_xticklabels([f'{row.Dataset}\n{row["Kernel Type"]}' for _, row in df.iterrows()], rotation=45, ha="right")

# Adding a legend
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# cifar10_simclr reproduction_log.txt
# cifar10_exponential_log.txt
# cifar10_simple sum_log.txt
# cifar10_concatenation_log.txt
# cifar10_rbf_log.txt
# cifar10_sigmoid_log.txt
# cifar10_Matern_log.txt
# cifar10_laplacian_log.txt
# cifar100_simclr reproduction_log.txt
# cifar100_exponential_log.txt
# cifar100_simple sum_log.txt
# cifar100_concatenation_log.txt
# cifar100_rbf_log.txt
# cifar100_sigmoid_log.txt
# cifar100_Matern_log.txt
# cifar100_laplacian_log.txt
